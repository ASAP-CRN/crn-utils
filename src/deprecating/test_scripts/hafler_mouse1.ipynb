# %% [markdown]
# ASAP CRN Metadata validation
#
# # Team Hafler. ASAP CRN Metadata validation
#
# 9 Oct 2024
# Andy Henrie

# %%
import pandas as pd
from pathlib import Path
import os, sys

sys.path.append(os.path.abspath((os.path.join(os.getcwd(), 'src/crn_utils'))))

from util import read_CDE, NULL, prep_table, read_meta_table
from validate import validate_table, ReportCollector
from update_schema import v1_to_v2, v2_to_v3_PMDBS, intervention_typer, create_upload_medadata_package
from checksums import get_md5_hashes, authenticate_with_service_account

# %load_ext autoreload
# %autoreload 2

root_path = Path.home() / ("Projects/ASAP/data/teams")
# Out:
# Streamlit NOT successfully imported

# %% [markdown]
# ## CDEs
# load the relavent CDEs

# %%
schema_version = "v1"
schema_path = Path.home() / "Projects/ASAP/crn-utils/resource/CDE"
CDEv1 = read_CDE(schema_version, local_path=schema_path)
schema_version = "v2.1"
CDEv2 = read_CDE(schema_version, local_path=schema_path)
schema_version = "v3.0"
CDEv3 = read_CDE(schema_version, local_path=schema_path)
# Out:
# metadata_version: ASAP_CDE_v1
# https://docs.google.com/spreadsheets/d/1c0z5KvRELdT2AtQAH2Dus8kwAyyLrR0CROhKOjpU4Vc/gviz/tq?tqx=out:csv&sheet=v1
# /Users/ergonyc/Projects/ASAP/crn-utils/resource/CDE/ASAP_CDE_v1.csv
# read local file
# metadata_version: ASAP_CDE_v2.1
# https://docs.google.com/spreadsheets/d/1c0z5KvRELdT2AtQAH2Dus8kwAyyLrR0CROhKOjpU4Vc/gviz/tq?tqx=out:csv&sheet=v2.1
# /Users/ergonyc/Projects/ASAP/crn-utils/resource/CDE/ASAP_CDE_v2.1.csv
# read local file
# metadata_version: ASAP_CDE_v3.0
# https://docs.google.com/spreadsheets/d/1c0z5KvRELdT2AtQAH2Dus8kwAyyLrR0CROhKOjpU4Vc/gviz/tq?tqx=out:csv&sheet=v3.0
# /Users/ergonyc/Projects/ASAP/crn-utils/resource/CDE/ASAP_CDE_v3.0.csv
# read local file

# %% [markdown]
# > SANITY CHECK: verify reading from google doc works.
#
# ```python
# CDEv1_ = read_CDE("v1")
# CDEv2_ = read_CDE("v2.1")
# CDEv3_ = read_CDE("v3.0")
# ```

# %% [markdown]
# ## Load original tables
# These were submitted as v1.0

# %% [markdown]
# Team Hafler

# %%
## convert 
team = "hafler"
dataset_name = "sn-rnaseq-pfc"


metadata_path = root_path / f"{team}/{dataset_name}/metadata"

sheets = ["SAMPLE","SUBJECT","CLINPATH","STUDY","PROTOCOL"]
excel_path = metadata_path / "og/ASAP_CDE_ALL_Team_Hafler_v1.xlsx"
STUDY = pd.read_excel(excel_path,sheet_name="STUDY",header=1).drop(columns="Field")
CLINPATH = pd.read_excel(excel_path,sheet_name="CLINPATH",header=1).drop(columns="Field")
SUBJECT = pd.read_excel(excel_path,sheet_name="SUBJECT",header=1).drop(columns="Field")
SAMPLE = pd.read_excel(excel_path,sheet_name="SAMPLE",header=1).drop(columns="Field")
PROTOCOL = pd.read_excel(excel_path,sheet_name="PROTOCOL",header=1).drop(columns="Field")
metadata_path
# Out:
# PosixPath('/Users/ergonyc/Projects/ASAP/data/teams/hafler/sn-rnaseq-pfc/metadata')

# %%
def add_hafler_batch(sample_df):

    # First batch: HSDG07HC HSDG10HC HSDG148PD HSDG199PD
    # batch[batch.sample_id in ['hSDG07HC', 'hSDG10HC', 'hSDG148PD', 'hSDG199PD']]=1
    Batch_1 = ['hSDG07', 'hSDG10', 'hSDG148', 'hSDG199'] 
    # Second batch: hsDG101HC hsDG13HC hsDG151PD hsDG197PD hsDG30HC hsDG99HC
    Batch_2 = ['hSDG101', 'hSDG13', 'hSDG151', 'hSDG197', 'hSDG30', 'hSDG99']
    # Third batch: hsDG142PD hsDG208PD
    Batch_3 = ['hSDG142', 'hSDG208'] 


    batch_col = []
    for row in sample_df.sample_id:
        if row in Batch_1:
            batch_col.append("Batch_1")
        elif row in Batch_2:
            batch_col.append("Batch_2")
        elif row in Batch_3:
            batch_col.append("Batch_3")
        else:
            print("ERROR >>>>>>>> not no batch info")
            batch_col.append("")


    sample_df['batch'] = batch_col
    return sample_df

SAMPLE = add_hafler_batch(SAMPLE)

# %%
# fix replicate & replicate_count
SAMPLE.replace("Nan", "", inplace=True)

SAMPLE['replicate'] = "Rep1"
SAMPLE['replicate_count'] = 1

SAMPLE.head()
# Out:
#   sample_id source_sample_id subject_id replicate  replicate_count  \
# 0    hSDG07           hSDG07       HC01      Rep1                1
# 1    hSDG07           hSDG07       HC01      Rep1                1
# 2    hSDG07           hSDG07       HC01      Rep1                1
# 3   hSDG101          hSDG101       HC03      Rep1                1
# 4   hSDG101          hSDG101       HC03      Rep1                1
#
#    repeated_sample    batch tissue       brain_region  source_RIN  ...  \
# 0                0  Batch_1  Brain  Prefrontal Cortex         NaN  ...
# 1                0  Batch_1  Brain  Prefrontal Cortex         NaN  ...
# 2                0  Batch_1  Brain  Prefrontal Cortex         NaN  ...
# 3                0  Batch_2  Brain  Prefrontal Cortex         NaN  ...
# 4                0  Batch_2  Brain  Prefrontal Cortex         NaN  ...
#
#    sex_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0                   NaN                                      NaN
# 1                   NaN                                      NaN
# 2                   NaN                                      NaN
# 3                   NaN                                      NaN
# 4                   NaN                                      NaN
#
#   disease_ontology_term_id tissue_ontology_term_id cell_type_ontology_term_id  \
# 0                      NaN                     NaN                        NaN
# 1                      NaN                     NaN                        NaN
# 2                      NaN                     NaN                        NaN
# 3                      NaN                     NaN                        NaN
# 4                      NaN                     NaN                        NaN
#
#   assay_ontology_term_id suspension_type DV2000 pm_PH  donor_id
# 0                    NaN             NaN    NaN   NaN       NaN
# 1                    NaN             NaN    NaN   NaN       NaN
# 2                    NaN             NaN    NaN   NaN       NaN
# 3                    NaN             NaN    NaN   NaN       NaN
# 4                    NaN             NaN    NaN   NaN       NaN
#
# [5 rows x 42 columns]

# %%
STUDY = prep_table(STUDY, CDEv1)
STUDY['metadata_version_date']
STUDY.rename(columns={"submittor_email":"submitter_email"}, inplace=True)

# %%
SUBJECT.replace("Nan", "", inplace=True)

# %%
SUBJECT = prep_table(SUBJECT, CDEv1)

# %%
SUBJECT['sex'] = SUBJECT['sex'].replace({'F':"Female", 'M':"Male"})
SUBJECT['race'] = SUBJECT['race'].replace({'W':"White", 'B':"Black or African American"})

SUBJECT['primary_diagnosis'] = SUBJECT['primary_diagnosis'].replace({'Normal control':"Healthy Control", "Idiopathic Parkinson's disease":"Idiopathic PD"})

# %%
# they "race" was reported under ethnicity, so code as "Not Reported"
SUBJECT['ethnicity'] = 'Not Reported'

# %%
SUBJECT[['subject_id', 'source_subject_id']]
# Out:
#    subject_id source_subject_id
# 0        HC01            hSDG07
# 1        HC02            hSDG13
# 2        HC03           hSDG101
# 3        HC04            hSDG10
# 4        HC05            hSDG30
# 5        HC06            hSDG99
# 6        PD01           hSDG151
# 7        PD02           hSDG197
# 8        PD03           hSDG208
# 9        PD04           hSDG142
# 10       PD05           hSDG148
# 11       PD06           hSDG199

# %%
SAMPLE = prep_table(SAMPLE,  CDEv1)

# %%
# force the right sex_ontology_term_id
SAMPLE["organism_ontology_term_id"] = "NCBITaxon:9606"

# set time == 0 for all samples
SAMPLE['time'] = 0

SAMPLE['file_type'] = SAMPLE['file_type'].replace({"Fastq":"fastq"})

# %%
# need to join with subject to get "sex" and convert to ontology term
SAMPLE_SUBJECT = SAMPLE.merge(SUBJECT, on='subject_id',  how='left')
SAMPLE_og = SAMPLE.copy()
SAMPLE['sex_ontology_term_id'] = SAMPLE_SUBJECT['sex'].replace({"Male":"PATO:0000384 (male)", "Female":"PATO:0000383 (female)" })

# ignore development_stage_ontology_term_id, self_reported_ethnicity_ontology_term_id, assay_ontology_term_id, etc for now. (Check wiht Le)

# %%
# fix assay
SAMPLE['assay'] = SAMPLE['assay'].replace({'v3.1 - Single Index, 10x Genomics ':"v3.1 - Single Index"})
# fix assay
SAMPLE['sequencing_length'] = SAMPLE['sequencing_length'].replace({'150bp x2':"150"})

# fix DV200 
SAMPLE.rename(columns={"DV2000":"DV200"}, inplace=True)
#TODO: add file_description I1, R1, R2  "Raw sequencing data"

# %%
SAMPLE['input_cell_count'] = 8000

# %%
SAMPLE[['sample_id','subject_id','source_sample_id','file_name','file_MD5']]
# Out:
#    sample_id subject_id source_sample_id  \
# 0     hSDG07       HC01           hSDG07
# 1     hSDG07       HC01           hSDG07
# 2     hSDG07       HC01           hSDG07
# 3    hSDG101       HC03          hSDG101
# 4    hSDG101       HC03          hSDG101
# 5    hSDG101       HC03          hSDG101
# 6     hSDG10       HC04           hSDG10
# 7     hSDG10       HC04           hSDG10
# 8     hSDG10       HC04           hSDG10
# 9     hSDG13       HC02           hSDG13
# 10    hSDG13       HC02           hSDG13
# 11    hSDG13       HC02           hSDG13
# 12   hSDG142       PD04          hSDG142
# 13   hSDG142       PD04          hSDG142
# 14   hSDG142       PD04          hSDG142
# 15   hSDG148       PD05          hSDG148
# 16   hSDG148       PD05          hSDG148
# 17   hSDG148       PD05          hSDG148
# 18   hSDG151       PD01          hSDG151
# 19   hSDG151       PD01          hSDG151
# 20   hSDG151       PD01          hSDG151
# 21   hSDG197       PD02          hSDG197
# 22   hSDG197       PD02          hSDG197
# 23   hSDG197       PD02          hSDG197
# 24   hSDG199       PD06          hSDG199
# 25   hSDG199       PD06          hSDG199
# 26   hSDG199       PD06          hSDG199
# 27   hSDG208       PD03          hSDG208
# 28   hSDG208       PD03          hSDG208
# 29   hSDG208       PD03          hSDG208
# 30    hSDG30       HC05           hSDG30
# 31    hSDG30       HC05           hSDG30
# 32    hSDG30       HC05           hSDG30
# 33    hSDG99       HC06           hSDG99
# 34    hSDG99       HC06           hSDG99
# 35    hSDG99       HC06           hSDG99
#
#                                 file_name                            file_MD5
# 0    HSDG07HC_HHT_S6_L004_I1_001.fastq.gz  37912362469bc61a936dcc39a2b75138
# 1    HSDG07HC_HHT_S6_L004_R1_001.fastq.gz  b4d94bd92286d318de2b013ea44c5246
# 2    HSDG07HC_HHT_S6_L004_R2_001.fastq.gz  2a3c2c2303948f15d74b89ae4cbff409
# 3   hsDG101HC_HHT_S2_L002_I1_001.fastq.gz  1fbdbaba5e604aa852b9dc6af9e3dea4
# 4   hsDG101HC_HHT_S2_L002_R1_001.fastq.gz  3e14c63f5c55b4f29fcb0b1af5992924
# 5   hsDG101HC_HHT_S2_L002_R2_001.fastq.gz  f34b13c20fd03611b5772037bac11b37
# 6    HSDG10HC_HHT_S7_L004_I1_001.fastq.gz  7649f0db658f8d697b82a0ddc2dfedad
# 7    HSDG10HC_HHT_S7_L004_R1_001.fastq.gz  309aa23c50a13bb99ad88cdc4579d77d
# 8    HSDG10HC_HHT_S7_L004_R2_001.fastq.gz  187af38f53ba8b760e1da2e3fe602051
# 9    hsDG13HC_HHT_S1_L002_I1_001.fastq.gz  d3b2e5364b57bfa4a1f50166a9043949
# 10   hsDG13HC_HHT_S1_L002_R1_001.fastq.gz  cf03854826d72aa3354d85b8ffec3158
# 11   hsDG13HC_HHT_S1_L002_R2_001.fastq.gz  57a3c24d9e5ac37f0ade89fab5d81221
# 12  hsDG142PD_HHT_S1_L004_I1_001.fastq.gz  82611cc7310f320e55c4e7d4f9deaa6c
# 13  hsDG142PD_HHT_S1_L004_R1_001.fastq.gz  efbfc22c4f70229cc55d9ce0a9666905
# 14  hsDG142PD_HHT_S1_L004_R2_001.fastq.gz  d81f41953ccfd7a19f0d8f7b40331a94
# 15  HSDG148PD_HHT_S8_L004_I1_001.fastq.gz  4fb24e5f1d013e9d3e9bddae257f13d7
# 16  HSDG148PD_HHT_S8_L004_R1_001.fastq.gz  7b5044a879fd6834da717bf30d567886
# 17  HSDG148PD_HHT_S8_L004_R2_001.fastq.gz  5160b193d2b027cff273cef8a498d18e
# 18  hsDG151PD_HHT_S3_L002_I1_001.fastq.gz  9fc42644fb0c172f7c763508c7ff487d
# 19  hsDG151PD_HHT_S3_L002_R1_001.fastq.gz  8a7864b884370cd471535458b0b1af36
# 20  hsDG151PD_HHT_S3_L002_R2_001.fastq.gz  f5df7869c3abb4cbb9a39744b52e735e
# 21  hsDG197PD_HHT_S4_L002_I1_001.fastq.gz  72c306e8e62f1e1aca40683d64b193e6
# 22  hsDG197PD_HHT_S4_L002_R1_001.fastq.gz  c25bd6667d2f26321c8e487fd03c0ccb
# 23  hsDG197PD_HHT_S4_L002_R2_001.fastq.gz  5468c04e562afefe9c5a8f2ce681da48
# 24  HSDG199PD_HHT_S9_L004_I1_001.fastq.gz  75e812687ceaaac3fb3b96f975ed882c
# 25  HSDG199PD_HHT_S9_L004_R1_001.fastq.gz  0c366114bd1c8a32fae4c5bc7fd5a827
# 26  HSDG199PD_HHT_S9_L004_R2_001.fastq.gz  5e341720064bed715b7615503f52e9fd
# 27  hsDG208PD_HHT_S2_L004_I1_001.fastq.gz  e2c83faf07f6773f17e97cc15982e31e
# 28  hsDG208PD_HHT_S2_L004_R1_001.fastq.gz  54785f282faa08feccfbc36909c3b813
# 29  hsDG208PD_HHT_S2_L004_R2_001.fastq.gz  9c0805328e0b507fdc550eec75945de1
# 30   hsDG30HC_HHT_S5_L002_I1_001.fastq.gz  25d8afaa03caef014cc524e123fbe4f1
# 31   hsDG30HC_HHT_S5_L002_R1_001.fastq.gz  800c3cba9ad5ba7e723a823185d8c6d7
# 32   hsDG30HC_HHT_S5_L002_R2_001.fastq.gz  33bb89ecc77864e941780ea5b51a1e78
# 33   hsDG99HC_HHT_S6_L002_I1_001.fastq.gz  4338a44166a8db22d17b505230cafb70
# 34   hsDG99HC_HHT_S6_L002_R1_001.fastq.gz  259872710e42ff48a06f7eb62d314044
# 35   hsDG99HC_HHT_S6_L002_R2_001.fastq.gz  f5e3940aac576c5110dbb7b2acdd7000

# %%
# clean MD5 hashes
SAMPLE['file_MD5'] = SAMPLE['file_MD5'].str.strip()
SAMPLE[['sample_id','subject_id','source_sample_id','file_name','file_MD5']]
# Out:
#    sample_id subject_id source_sample_id  \
# 0     hSDG07       HC01           hSDG07
# 1     hSDG07       HC01           hSDG07
# 2     hSDG07       HC01           hSDG07
# 3    hSDG101       HC03          hSDG101
# 4    hSDG101       HC03          hSDG101
# 5    hSDG101       HC03          hSDG101
# 6     hSDG10       HC04           hSDG10
# 7     hSDG10       HC04           hSDG10
# 8     hSDG10       HC04           hSDG10
# 9     hSDG13       HC02           hSDG13
# 10    hSDG13       HC02           hSDG13
# 11    hSDG13       HC02           hSDG13
# 12   hSDG142       PD04          hSDG142
# 13   hSDG142       PD04          hSDG142
# 14   hSDG142       PD04          hSDG142
# 15   hSDG148       PD05          hSDG148
# 16   hSDG148       PD05          hSDG148
# 17   hSDG148       PD05          hSDG148
# 18   hSDG151       PD01          hSDG151
# 19   hSDG151       PD01          hSDG151
# 20   hSDG151       PD01          hSDG151
# 21   hSDG197       PD02          hSDG197
# 22   hSDG197       PD02          hSDG197
# 23   hSDG197       PD02          hSDG197
# 24   hSDG199       PD06          hSDG199
# 25   hSDG199       PD06          hSDG199
# 26   hSDG199       PD06          hSDG199
# 27   hSDG208       PD03          hSDG208
# 28   hSDG208       PD03          hSDG208
# 29   hSDG208       PD03          hSDG208
# 30    hSDG30       HC05           hSDG30
# 31    hSDG30       HC05           hSDG30
# 32    hSDG30       HC05           hSDG30
# 33    hSDG99       HC06           hSDG99
# 34    hSDG99       HC06           hSDG99
# 35    hSDG99       HC06           hSDG99
#
#                                 file_name                          file_MD5
# 0    HSDG07HC_HHT_S6_L004_I1_001.fastq.gz  37912362469bc61a936dcc39a2b75138
# 1    HSDG07HC_HHT_S6_L004_R1_001.fastq.gz  b4d94bd92286d318de2b013ea44c5246
# 2    HSDG07HC_HHT_S6_L004_R2_001.fastq.gz  2a3c2c2303948f15d74b89ae4cbff409
# 3   hsDG101HC_HHT_S2_L002_I1_001.fastq.gz  1fbdbaba5e604aa852b9dc6af9e3dea4
# 4   hsDG101HC_HHT_S2_L002_R1_001.fastq.gz  3e14c63f5c55b4f29fcb0b1af5992924
# 5   hsDG101HC_HHT_S2_L002_R2_001.fastq.gz  f34b13c20fd03611b5772037bac11b37
# 6    HSDG10HC_HHT_S7_L004_I1_001.fastq.gz  7649f0db658f8d697b82a0ddc2dfedad
# 7    HSDG10HC_HHT_S7_L004_R1_001.fastq.gz  309aa23c50a13bb99ad88cdc4579d77d
# 8    HSDG10HC_HHT_S7_L004_R2_001.fastq.gz  187af38f53ba8b760e1da2e3fe602051
# 9    hsDG13HC_HHT_S1_L002_I1_001.fastq.gz  d3b2e5364b57bfa4a1f50166a9043949
# 10   hsDG13HC_HHT_S1_L002_R1_001.fastq.gz  cf03854826d72aa3354d85b8ffec3158
# 11   hsDG13HC_HHT_S1_L002_R2_001.fastq.gz  57a3c24d9e5ac37f0ade89fab5d81221
# 12  hsDG142PD_HHT_S1_L004_I1_001.fastq.gz  82611cc7310f320e55c4e7d4f9deaa6c
# 13  hsDG142PD_HHT_S1_L004_R1_001.fastq.gz  efbfc22c4f70229cc55d9ce0a9666905
# 14  hsDG142PD_HHT_S1_L004_R2_001.fastq.gz  d81f41953ccfd7a19f0d8f7b40331a94
# 15  HSDG148PD_HHT_S8_L004_I1_001.fastq.gz  4fb24e5f1d013e9d3e9bddae257f13d7
# 16  HSDG148PD_HHT_S8_L004_R1_001.fastq.gz  7b5044a879fd6834da717bf30d567886
# 17  HSDG148PD_HHT_S8_L004_R2_001.fastq.gz  5160b193d2b027cff273cef8a498d18e
# 18  hsDG151PD_HHT_S3_L002_I1_001.fastq.gz  9fc42644fb0c172f7c763508c7ff487d
# 19  hsDG151PD_HHT_S3_L002_R1_001.fastq.gz  8a7864b884370cd471535458b0b1af36
# 20  hsDG151PD_HHT_S3_L002_R2_001.fastq.gz  f5df7869c3abb4cbb9a39744b52e735e
# 21  hsDG197PD_HHT_S4_L002_I1_001.fastq.gz  72c306e8e62f1e1aca40683d64b193e6
# 22  hsDG197PD_HHT_S4_L002_R1_001.fastq.gz  c25bd6667d2f26321c8e487fd03c0ccb
# 23  hsDG197PD_HHT_S4_L002_R2_001.fastq.gz  5468c04e562afefe9c5a8f2ce681da48
# 24  HSDG199PD_HHT_S9_L004_I1_001.fastq.gz  75e812687ceaaac3fb3b96f975ed882c
# 25  HSDG199PD_HHT_S9_L004_R1_001.fastq.gz  0c366114bd1c8a32fae4c5bc7fd5a827
# 26  HSDG199PD_HHT_S9_L004_R2_001.fastq.gz  5e341720064bed715b7615503f52e9fd
# 27  hsDG208PD_HHT_S2_L004_I1_001.fastq.gz  e2c83faf07f6773f17e97cc15982e31e
# 28  hsDG208PD_HHT_S2_L004_R1_001.fastq.gz  54785f282faa08feccfbc36909c3b813
# 29  hsDG208PD_HHT_S2_L004_R2_001.fastq.gz  9c0805328e0b507fdc550eec75945de1
# 30   hsDG30HC_HHT_S5_L002_I1_001.fastq.gz  25d8afaa03caef014cc524e123fbe4f1
# 31   hsDG30HC_HHT_S5_L002_R1_001.fastq.gz  800c3cba9ad5ba7e723a823185d8c6d7
# 32   hsDG30HC_HHT_S5_L002_R2_001.fastq.gz  33bb89ecc77864e941780ea5b51a1e78
# 33   hsDG99HC_HHT_S6_L002_I1_001.fastq.gz  4338a44166a8db22d17b505230cafb70
# 34   hsDG99HC_HHT_S6_L002_R1_001.fastq.gz  259872710e42ff48a06f7eb62d314044
# 35   hsDG99HC_HHT_S6_L002_R2_001.fastq.gz  f5e3940aac576c5110dbb7b2acdd7000

# %%
# the CLINPATH has sample_id as a subject_id, so we need to fix that
subj_samp_mapper = dict(zip( SAMPLE['subject_id'], SAMPLE['sample_id']))
subj_samp_mapper
# Out:
# {'HC01': 'hSDG07',
#  'HC03': 'hSDG101',
#  'HC04': 'hSDG10',
#  'HC02': 'hSDG13',
#  'PD04': 'hSDG142',
#  'PD05': 'hSDG148',
#  'PD01': 'hSDG151',
#  'PD02': 'hSDG197',
#  'PD06': 'hSDG199',
#  'PD03': 'hSDG208',
#  'HC05': 'hSDG30',
#  'HC06': 'hSDG99'}

# %%
CLINPATH = prep_table(CLINPATH, CDEv1)
CLINPATH.rename(columns={"path_thai":"path_thal"}, inplace=True)
CLINPATH.replace("Nan", "", inplace=True)

# %%
# redact "Prefrontal Cortex" from region_level_2 for now
CLINPATH['region_level_2'] = CLINPATH['region_level_2'].replace({'Prefrontal Cortex':""})

# leave te APOE_e4_status as is for now . multiple are coded as "2,3" 
# but remove commas
CLINPATH["APOE_e4_status"] = CLINPATH["APOE_e4_status"].str.replace(",","")

# need to fix the path_autopsy_dx_main

# %%
CLINPATH[['sample_id', 'source_sample_id', 'time_from_baseline', 'GP2_id',
       'AMPPD_id']]
# Out:
#    sample_id source_sample_id time_from_baseline GP2_id AMPPD_id
# 0       HC01           hSDG07
# 1       HC02           hSDG13
# 2       HC03          hSDG101
# 3       HC04           hSDG10
# 4       HC05           hSDG30
# 5       HC06           hSDG99
# 6       PD01          hSDG151
# 7       PD02          hSDG197
# 8       PD03          hSDG208
# 9       PD04          hSDG142
# 10      PD05          hSDG148
# 11      PD06          hSDG199

# %%
CLINPATH['sample_id'].replace(subj_samp_mapper, inplace=True)
CLINPATH[['sample_id', 'source_sample_id', 'time_from_baseline', 'GP2_id',
       'AMPPD_id']]
# Out:
# /var/folders/0z/hvx6j8cn6yj3bqbyq6rtsxm40000gn/T/ipykernel_57365/2503552355.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   CLINPATH['sample_id'].replace(subj_samp_mapper, inplace=True)
#    sample_id source_sample_id time_from_baseline GP2_id AMPPD_id
# 0     hSDG07           hSDG07
# 1     hSDG13           hSDG13
# 2    hSDG101          hSDG101
# 3     hSDG10           hSDG10
# 4     hSDG30           hSDG30
# 5     hSDG99           hSDG99
# 6    hSDG151          hSDG151
# 7    hSDG197          hSDG197
# 8    hSDG208          hSDG208
# 9    hSDG142          hSDG142
# 10   hSDG148          hSDG148
# 11   hSDG199          hSDG199

# %%
# CLINPATH = CLINPATH.rename(columns={"source_sample_id":"source_subject_id"})
# CLINPATH["subject_id"] = CLINPATH["source_subject_id"].str.replace("hSDG","hSDG0")
STUDY
# Out:
#                                         project_name  \
# 0  Single-cell transcriptomic and proteomic analy...
#
#                                      project_dataset  \
# 0  Single nucleus RNA sequencing dataset of PD br...
#
#                                  project_description ASAP_team_name  \
# 0  We provide an extensive single cell analysis p...    TEAM-HAFLER
#
#   ASAP_lab_name PI_full_name           PI_email contributor_names  \
# 0  Le Zhang Lab     Le Zhang  Le.zhang@yale.edu          Le Zhang
#
#   submitter_name    submitter_email  ... other_funding_source  \
# 0       Le Zhang  le.zhang@yale.edu  ...                  Nan
#
#                                   publication_DOI publication_PMID  \
# 0  Doi: https://doi.org/10.1101/2022.02.14.480397              Nan
#
#   number_of_brain_samples      brain_regions  \
# 0                      12  Prefrontal cortex
#
#                               types_of_samples            PI_ORCHID  \
# 0  Late-stage PD and control postmortem brains  0000-0002-4860-831X
#
#   PI_google_scholar_id DUA_version metadata_version_date
# 0                  Nan         Nan         V1_08/27/2023
#
# [1 rows x 21 columns]

# %% [markdown]
# dump these extractions from the excel file as og

# %%
og_path = metadata_path / "og"
STUDY.to_csv(og_path / f"STUDY.csv", index=False)
SAMPLE.to_csv(og_path / f"SAMPLE.csv", index=False)
SUBJECT.to_csv(og_path / f"SUBJECT.csv", index=False)
PROTOCOL.to_csv(og_path / f"PROTOCOL.csv", index=False)
CLINPATH.to_csv(og_path / f"CLINPATH.csv", index=False)

# %% [markdown]
# ## validate v1
#
# QC these tables and make sure they are conformant

# %%
metadata_version = "v1"

METADATA_VERSION_DATE = f"{metadata_version}_{pd.Timestamp.now().strftime('%Y%m%d')}"

# %%
STUDY['metadata_version_date'] = METADATA_VERSION_DATE

# %%
CDE = CDEv1
tables = CDE['Table'].unique()
v1_path = metadata_path / "v1"

dfs = {}
for table in tables:
    df = read_meta_table(og_path / f"{table}.csv")
    schema = CDE[CDE['Table'] == table]

    report = ReportCollector(destination="NA")
    full_table, report = validate_table(df.copy(), table, schema, report)
    report.print_log()
    dfs[table] = full_table
    df.to_csv(v1_path / f"{table}.csv", index=False)
# Out:
# recoding number_of_brain_samples as int
# All required fields are present in *STUDY* table.
# 🚨⚠️❗ **4 Fields with empty (NULL) values:**
#
# 	- other_funding_source: 1/1 empty rows (REQUIRED)
#
# 	- publication_PMID: 1/1 empty rows (REQUIRED)
#
# 	- PI_google_scholar_id: 1/1 empty rows (OPTIONAL)
#
# 	- DUA_version: 1/1 empty rows (REQUIRED)
# No invalid entries found in Enum fields.
#
# All required fields are present in *SUBJECT* table.
# 🚨⚠️❗ **1 Fields with empty (NULL) values:**
#
# 	- primary_diagnosis_text: 12/12 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# recoding input_cell_count as int
# All required fields are present in *SAMPLE* table.
# 🚨⚠️❗ **17 Fields with empty (NULL) values:**
#
# 	- source_RIN: 36/36 empty rows (REQUIRED)
#
# 	- RIN: 36/36 empty rows (REQUIRED)
#
# 	- file_description: 36/36 empty rows (REQUIRED)
#
# 	- header: 36/36 empty rows (REQUIRED)
#
# 	- annotation: 36/36 empty rows (REQUIRED)
#
# 	- preprocessing_references: 36/36 empty rows (OPTIONAL)
#
# 	- configuration_file: 36/36 empty rows (REQUIRED)
#
# 	- development_stage_ontology_term_id: 36/36 empty rows (REQUIRED)
#
# 	- self_reported_ethnicity_ontology_term_id: 36/36 empty rows (REQUIRED)
#
# 	- disease_ontology_term_id: 36/36 empty rows (REQUIRED)
#
# 	- tissue_ontology_term_id: 36/36 empty rows (REQUIRED)
#
# 	- cell_type_ontology_term_id: 36/36 empty rows (REQUIRED)
#
# 	- assay_ontology_term_id: 36/36 empty rows (REQUIRED)
#
# 	- suspension_type: 36/36 empty rows (REQUIRED)
#
# 	- DV200: 36/36 empty rows (OPTIONAL)
#
# 	- pm_PH: 36/36 empty rows (OPTIONAL)
#
# 	- donor_id: 36/36 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *PROTOCOL* table.
# 🚨⚠️❗ **3 Fields with empty (NULL) values:**
#
# 	- github_url: 1/1 empty rows (REQUIRED)
#
# 	- protocols_io_DOI: 1/1 empty rows (REQUIRED)
#
# 	- other_reference: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# All required fields are present in *CLINPATH* table.
# 🚨⚠️❗ **Missing Optional Fields in CLINPATH: dig_slide_avail, quant_path_avail**
# 🚨⚠️❗ **43 Fields with empty (NULL) values:**
#
# 	- time_from_baseline: 12/12 empty rows (REQUIRED)
#
# 	- GP2_id: 12/12 empty rows (REQUIRED)
#
# 	- AMPPD_id: 12/12 empty rows (REQUIRED)
#
# 	- last_diagnosis: 12/12 empty rows (REQUIRED)
#
# 	- age_at_onset: 12/12 empty rows (REQUIRED)
#
# 	- age_at_diagnosis: 12/12 empty rows (REQUIRED)
#
# 	- first_motor_symptom: 12/12 empty rows (REQUIRED)
#
# 	- hx_dementia_mci: 12/12 empty rows (REQUIRED)
#
# 	- hx_melanoma: 12/12 empty rows (REQUIRED)
#
# 	- education_level: 12/12 empty rows (REQUIRED)
#
# 	- smoking_status: 12/12 empty rows (REQUIRED)
#
# 	- smoking_years: 12/12 empty rows (OPTIONAL)
#
# 	- APOE_e4_status: 1/12 empty rows (REQUIRED)
#
# 	- path_autopsy_dx_main: 6/12 empty rows (REQUIRED)
#
# 	- path_autopsy_second_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_third_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_fourth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_fifth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_sixth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_seventh_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_eight_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_year_death: 12/12 empty rows (REQUIRED)
#
# 	- cause_death: 12/12 empty rows (REQUIRED)
#
# 	- other_cause_death_1: 12/12 empty rows (OPTIONAL)
#
# 	- other_cause_death_2: 12/12 empty rows (OPTIONAL)
#
# 	- brain_weight: 12/12 empty rows (REQUIRED)
#
# 	- path_braak_nft: 12/12 empty rows (REQUIRED)
#
# 	- path_braak_asyn: 12/12 empty rows (REQUIRED)
#
# 	- path_cerad: 12/12 empty rows (REQUIRED)
#
# 	- path_thal: 12/12 empty rows (REQUIRED)
#
# 	- known_pathogenic_mutation: 12/12 empty rows (OPTIONAL)
#
# 	- PD_pathogenic_mutation: 12/12 empty rows (OPTIONAL)
#
# 	- path_mckeith: 12/12 empty rows (OPTIONAL)
#
# 	- sn_neuronal_loss: 12/12 empty rows (OPTIONAL)
#
# 	- path_infarcs: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_ri: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_a: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_b: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_c: 12/12 empty rows (OPTIONAL)
#
# 	- TDP43: 12/12 empty rows (OPTIONAL)
#
# 	- arteriolosclerosis_severity_scale: 12/12 empty rows (OPTIONAL)
#
# 	- amyloid_angiopathy_severity_scale: 12/12 empty rows (OPTIONAL)
#
# 	- path_ad_level: 12/12 empty rows (OPTIONAL)
# 🚨⚠️❗ **1 Fields with invalid entries:**
# - _*region_level_2*_:  invalid values 💩'Prefrontal cortex'
#     - valid ➡️ 'Superior frontal gyrus', 'Middle frontal gyrus', 'Inferior frontal gyrus', 'Superior temporal gyrus', 'Middle temporal gyrus', 'Inferior temporal gyrus', 'Fusiform gyrus', 'Transentorhinal region', 'Entorinal region', 'Subiculum', 'CA1-CA4', 'Amygdala', 'Periamygdala cortex', 'Anterior cingulate gyrus', 'Posterior cingulate gyrus', 'Superior parietal lobule', 'Inferior parietal lobule', 'Parastriate cortex', 'Peristriate cortex', 'Striate cortex', 'Insular cortex', 'Caudate nucleus', 'Putamen', 'Globus pallidus', 'Thalamus', 'Subthalamic nucleus', 'Substantia nigra', 'Pontine tegmentum', 'Pontine base', 'Medulla tegmentum', 'Medulla base', 'Cerebellar vermis', 'Cerebellar hemisphere', 'Dentate nucleus', 'Right colon', 'Left colon', 'Unknown', 'NA'

# %%
# make tables conform to CDE and save extra columns as "auxiliary"

for table in tables:
    df = dfs[table]
    schema = CDE[CDE['Table'] == table]
    valid_fields = schema['Field'].unique()
    df_out = df[valid_fields]
    aux_fields = set(df.columns) - set(valid_fields)
    if aux_fields:
        df_aux = df[list(aux_fields)]
        df_aux.to_csv(v1_path / f"{table}_auxiliary.csv", index=False)
        print(f"Saved {table}_auxiliary.csv")
    df_out.to_csv(v1_path / f"{table}.csv", index=False)

# %%
dfs['SAMPLE'][['sample_id','subject_id','source_sample_id','file_name','file_MD5']]
# Out:
#    sample_id subject_id source_sample_id  \
# 0     hSDG07       HC01           hSDG07
# 1     hSDG07       HC01           hSDG07
# 2     hSDG07       HC01           hSDG07
# 3    hSDG101       HC03          hSDG101
# 4    hSDG101       HC03          hSDG101
# 5    hSDG101       HC03          hSDG101
# 6     hSDG10       HC04           hSDG10
# 7     hSDG10       HC04           hSDG10
# 8     hSDG10       HC04           hSDG10
# 9     hSDG13       HC02           hSDG13
# 10    hSDG13       HC02           hSDG13
# 11    hSDG13       HC02           hSDG13
# 12   hSDG142       PD04          hSDG142
# 13   hSDG142       PD04          hSDG142
# 14   hSDG142       PD04          hSDG142
# 15   hSDG148       PD05          hSDG148
# 16   hSDG148       PD05          hSDG148
# 17   hSDG148       PD05          hSDG148
# 18   hSDG151       PD01          hSDG151
# 19   hSDG151       PD01          hSDG151
# 20   hSDG151       PD01          hSDG151
# 21   hSDG197       PD02          hSDG197
# 22   hSDG197       PD02          hSDG197
# 23   hSDG197       PD02          hSDG197
# 24   hSDG199       PD06          hSDG199
# 25   hSDG199       PD06          hSDG199
# 26   hSDG199       PD06          hSDG199
# 27   hSDG208       PD03          hSDG208
# 28   hSDG208       PD03          hSDG208
# 29   hSDG208       PD03          hSDG208
# 30    hSDG30       HC05           hSDG30
# 31    hSDG30       HC05           hSDG30
# 32    hSDG30       HC05           hSDG30
# 33    hSDG99       HC06           hSDG99
# 34    hSDG99       HC06           hSDG99
# 35    hSDG99       HC06           hSDG99
#
#                                 file_name                          file_MD5
# 0    HSDG07HC_HHT_S6_L004_I1_001.fastq.gz  37912362469bc61a936dcc39a2b75138
# 1    HSDG07HC_HHT_S6_L004_R1_001.fastq.gz  b4d94bd92286d318de2b013ea44c5246
# 2    HSDG07HC_HHT_S6_L004_R2_001.fastq.gz  2a3c2c2303948f15d74b89ae4cbff409
# 3   hsDG101HC_HHT_S2_L002_I1_001.fastq.gz  1fbdbaba5e604aa852b9dc6af9e3dea4
# 4   hsDG101HC_HHT_S2_L002_R1_001.fastq.gz  3e14c63f5c55b4f29fcb0b1af5992924
# 5   hsDG101HC_HHT_S2_L002_R2_001.fastq.gz  f34b13c20fd03611b5772037bac11b37
# 6    HSDG10HC_HHT_S7_L004_I1_001.fastq.gz  7649f0db658f8d697b82a0ddc2dfedad
# 7    HSDG10HC_HHT_S7_L004_R1_001.fastq.gz  309aa23c50a13bb99ad88cdc4579d77d
# 8    HSDG10HC_HHT_S7_L004_R2_001.fastq.gz  187af38f53ba8b760e1da2e3fe602051
# 9    hsDG13HC_HHT_S1_L002_I1_001.fastq.gz  d3b2e5364b57bfa4a1f50166a9043949
# 10   hsDG13HC_HHT_S1_L002_R1_001.fastq.gz  cf03854826d72aa3354d85b8ffec3158
# 11   hsDG13HC_HHT_S1_L002_R2_001.fastq.gz  57a3c24d9e5ac37f0ade89fab5d81221
# 12  hsDG142PD_HHT_S1_L004_I1_001.fastq.gz  82611cc7310f320e55c4e7d4f9deaa6c
# 13  hsDG142PD_HHT_S1_L004_R1_001.fastq.gz  efbfc22c4f70229cc55d9ce0a9666905
# 14  hsDG142PD_HHT_S1_L004_R2_001.fastq.gz  d81f41953ccfd7a19f0d8f7b40331a94
# 15  HSDG148PD_HHT_S8_L004_I1_001.fastq.gz  4fb24e5f1d013e9d3e9bddae257f13d7
# 16  HSDG148PD_HHT_S8_L004_R1_001.fastq.gz  7b5044a879fd6834da717bf30d567886
# 17  HSDG148PD_HHT_S8_L004_R2_001.fastq.gz  5160b193d2b027cff273cef8a498d18e
# 18  hsDG151PD_HHT_S3_L002_I1_001.fastq.gz  9fc42644fb0c172f7c763508c7ff487d
# 19  hsDG151PD_HHT_S3_L002_R1_001.fastq.gz  8a7864b884370cd471535458b0b1af36
# 20  hsDG151PD_HHT_S3_L002_R2_001.fastq.gz  f5df7869c3abb4cbb9a39744b52e735e
# 21  hsDG197PD_HHT_S4_L002_I1_001.fastq.gz  72c306e8e62f1e1aca40683d64b193e6
# 22  hsDG197PD_HHT_S4_L002_R1_001.fastq.gz  c25bd6667d2f26321c8e487fd03c0ccb
# 23  hsDG197PD_HHT_S4_L002_R2_001.fastq.gz  5468c04e562afefe9c5a8f2ce681da48
# 24  HSDG199PD_HHT_S9_L004_I1_001.fastq.gz  75e812687ceaaac3fb3b96f975ed882c
# 25  HSDG199PD_HHT_S9_L004_R1_001.fastq.gz  0c366114bd1c8a32fae4c5bc7fd5a827
# 26  HSDG199PD_HHT_S9_L004_R2_001.fastq.gz  5e341720064bed715b7615503f52e9fd
# 27  hsDG208PD_HHT_S2_L004_I1_001.fastq.gz  e2c83faf07f6773f17e97cc15982e31e
# 28  hsDG208PD_HHT_S2_L004_R1_001.fastq.gz  54785f282faa08feccfbc36909c3b813
# 29  hsDG208PD_HHT_S2_L004_R2_001.fastq.gz  9c0805328e0b507fdc550eec75945de1
# 30   hsDG30HC_HHT_S5_L002_I1_001.fastq.gz  25d8afaa03caef014cc524e123fbe4f1
# 31   hsDG30HC_HHT_S5_L002_R1_001.fastq.gz  800c3cba9ad5ba7e723a823185d8c6d7
# 32   hsDG30HC_HHT_S5_L002_R2_001.fastq.gz  33bb89ecc77864e941780ea5b51a1e78
# 33   hsDG99HC_HHT_S6_L002_I1_001.fastq.gz  4338a44166a8db22d17b505230cafb70
# 34   hsDG99HC_HHT_S6_L002_R1_001.fastq.gz  259872710e42ff48a06f7eb62d314044
# 35   hsDG99HC_HHT_S6_L002_R2_001.fastq.gz  f5e3940aac576c5110dbb7b2acdd7000

# %% [markdown]
# ## v1->v2

# %%
v2_path = metadata_path / "v2"

team_dataset_id = dataset_name.replace(" ", "_").replace("-", "_")

v2_tables, aux_tables = v1_to_v2(v1_path, v2_path, CDEv1, CDEv2, team_dataset_id=team_dataset_id)

# STUDYv2, PROTOCOLv2, SAMPLEv2, SUBJECTv2, CLINPATHv2, DATAv2 = v2_tables
# Out:
# recoding number_of_brain_samples as int
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# recoding replicate_count as int
# recoding repeated_sample as int
# recoding input_cell_count as int

# %%
v2_tables['STUDY']
# Out:
#   ASAP_team_name ASAP_lab_name  \
# 0    TEAM-HAFLER  Le Zhang Lab
#
#                                         project_name team_dataset_id  \
# 0  Single-cell transcriptomic and proteomic analy...   sn_rnaseq_pfc
#
#                                      project_dataset  \
# 0  Single nucleus RNA sequencing dataset of PD br...
#
#                                  project_description PI_full_name  \
# 0  We provide an extensive single cell analysis p...     Le Zhang
#
#             PI_email contributor_names submitter_name  ... publication_PMID  \
# 0  Le.zhang@yale.edu          Le Zhang       Le Zhang  ...               NA
#
#   number_of_brain_samples      brain_regions  \
# 0                      12  Prefrontal cortex
#
#                               types_of_samples            PI_ORCHID  \
# 0  Late-stage PD and control postmortem brains  0000-0002-4860-831X
#
#   PI_google_scholar_id DUA_version preprocessing_references  \
# 0                   NA          NA                       NA
#
#   metadata_version_date alternate_dataset_id
# 0         v2.1_20241028                   NA
#
# [1 rows x 24 columns]

# %% [markdown]
# ### validate v2 tables

# %%
CDE = CDEv2
for table,df in v2_tables.items():
    schema = CDE[CDE['Table'] == table]

    report = ReportCollector(destination="NA")
    full_table, report = validate_table(df.copy(), table, schema, report)
    report.print_log()
# Out:
# recoding number_of_brain_samples as int
# All required fields are present in *STUDY* table.
# 🚨⚠️❗ **6 Fields with empty (NULL) values:**
#
# 	- other_funding_source: 1/1 empty rows (REQUIRED)
#
# 	- publication_PMID: 1/1 empty rows (REQUIRED)
#
# 	- PI_google_scholar_id: 1/1 empty rows (OPTIONAL)
#
# 	- DUA_version: 1/1 empty rows (REQUIRED)
#
# 	- preprocessing_references: 1/1 empty rows (OPTIONAL)
#
# 	- alternate_dataset_id: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *PROTOCOL* table.
# 🚨⚠️❗ **3 Fields with empty (NULL) values:**
#
# 	- github_url: 1/1 empty rows (REQUIRED)
#
# 	- protocols_io_DOI: 1/1 empty rows (REQUIRED)
#
# 	- other_reference: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# All required fields are present in *SUBJECT* table.
# 🚨⚠️❗ **15 Fields with empty (NULL) values:**
#
# 	- AMPPD_id: 12/12 empty rows (REQUIRED)
#
# 	- GP2_id: 12/12 empty rows (REQUIRED)
#
# 	- family_history: 12/12 empty rows (REQUIRED)
#
# 	- last_diagnosis: 12/12 empty rows (REQUIRED)
#
# 	- age_at_onset: 12/12 empty rows (REQUIRED)
#
# 	- age_at_diagnosis: 12/12 empty rows (REQUIRED)
#
# 	- first_motor_symptom: 12/12 empty rows (REQUIRED)
#
# 	- hx_dementia_mci: 12/12 empty rows (REQUIRED)
#
# 	- hx_melanoma: 12/12 empty rows (REQUIRED)
#
# 	- education_level: 12/12 empty rows (REQUIRED)
#
# 	- smoking_status: 12/12 empty rows (REQUIRED)
#
# 	- smoking_years: 12/12 empty rows (OPTIONAL)
#
# 	- APOE_e4_status: 1/12 empty rows (REQUIRED)
#
# 	- time_from_baseline: 12/12 empty rows (REQUIRED)
#
# 	- primary_diagnosis_text: 12/12 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *CLINPATH* table.
# 🚨⚠️❗ **32 Fields with empty (NULL) values:**
#
# 	- path_autopsy_dx_main: 6/12 empty rows (REQUIRED)
#
# 	- path_autopsy_second_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_third_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_fourth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_fifth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_sixth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_seventh_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_eight_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_year_death: 12/12 empty rows (REQUIRED)
#
# 	- cause_death: 12/12 empty rows (REQUIRED)
#
# 	- other_cause_death_1: 12/12 empty rows (OPTIONAL)
#
# 	- other_cause_death_2: 12/12 empty rows (OPTIONAL)
#
# 	- brain_weight: 12/12 empty rows (REQUIRED)
#
# 	- path_braak_nft: 12/12 empty rows (REQUIRED)
#
# 	- path_braak_asyn: 12/12 empty rows (REQUIRED)
#
# 	- path_cerad: 12/12 empty rows (REQUIRED)
#
# 	- path_thal: 12/12 empty rows (REQUIRED)
#
# 	- known_pathogenic_mutation: 12/12 empty rows (OPTIONAL)
#
# 	- PD_pathogenic_mutation: 12/12 empty rows (OPTIONAL)
#
# 	- path_mckeith: 12/12 empty rows (OPTIONAL)
#
# 	- sn_neuronal_loss: 12/12 empty rows (OPTIONAL)
#
# 	- path_infarcs: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_ri: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_a: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_b: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_c: 12/12 empty rows (OPTIONAL)
#
# 	- TDP43: 12/12 empty rows (OPTIONAL)
#
# 	- arteriolosclerosis_severity_scale: 12/12 empty rows (OPTIONAL)
#
# 	- amyloid_angiopathy_severity_scale: 12/12 empty rows (OPTIONAL)
#
# 	- path_ad_level: 12/12 empty rows (OPTIONAL)
#
# 	- dig_slide_avail: 12/12 empty rows (OPTIONAL)
#
# 	- quant_path_avail: 12/12 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# recoding input_cell_count as int
# All required fields are present in *SAMPLE* table.
# 🚨⚠️❗ **14 Fields with empty (NULL) values:**
#
# 	- hemisphere: 12/12 empty rows (REQUIRED)
#
# 	- RIN: 12/12 empty rows (REQUIRED)
#
# 	- source_RIN: 12/12 empty rows (REQUIRED)
#
# 	- development_stage_ontology_term_id: 12/12 empty rows (REQUIRED)
#
# 	- self_reported_ethnicity_ontology_term_id: 12/12 empty rows (REQUIRED)
#
# 	- disease_ontology_term_id: 12/12 empty rows (REQUIRED)
#
# 	- tissue_ontology_term_id: 12/12 empty rows (REQUIRED)
#
# 	- cell_type_ontology_term_id: 12/12 empty rows (REQUIRED)
#
# 	- assay_ontology_term_id: 12/12 empty rows (REQUIRED)
#
# 	- suspension_type: 12/12 empty rows (REQUIRED)
#
# 	- DV200: 12/12 empty rows (OPTIONAL)
#
# 	- pm_PH: 12/12 empty rows (OPTIONAL)
#
# 	- donor_id: 12/12 empty rows (OPTIONAL)
#
# 	- alternate_sample_id: 12/12 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# All required fields are present in *DATA* table.
# 🚨⚠️❗ **4 Fields with empty (NULL) values:**
#
# 	- file_description: 36/36 empty rows (REQUIRED)
#
# 	- header: 36/36 empty rows (REQUIRED)
#
# 	- annotation: 36/36 empty rows (REQUIRED)
#
# 	- configuration_file: 36/36 empty rows (REQUIRED)
# No invalid entries found in Enum fields.

# %% [markdown]
# ## v2->v3

# %%
v3_meta_tables = ['STUDY', 'PROTOCOL', 'SUBJECT', 'SAMPLE', 'DATA', 'CLINPATH', 'PMDBS', 'CONDITION', 'ASSAY_RNAseq']

f"{v3_meta_tables}"
# Out:
# "['STUDY', 'PROTOCOL', 'SUBJECT', 'SAMPLE', 'DATA', 'CLINPATH', 'PMDBS', 'CONDITION', 'ASSAY_RNAseq']"

# %%
v3_path = metadata_path / "v3"

v3_tables, aux_tables = v2_to_v3_PMDBS(v2_path, v3_path, CDEv2, CDEv3)
# Out:
# recoding number_of_brain_samples as int
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# recoding replicate_count as int
# recoding repeated_sample as int
# recoding input_cell_count as int
# recoding replicate_count as int
# recoding repeated_sample as int

# %%
v3_tables.keys()
# Out:
# dict_keys(['STUDY', 'PROTOCOL', 'SUBJECT', 'SAMPLE', 'DATA', 'PMDBS', 'ASSAY_RNAseq', 'CLINPATH', 'CONDITION'])

# %%
v3_tables['STUDY']
# Out:
#   ASAP_team_name ASAP_lab_name  \
# 0    TEAM-HAFLER  Le Zhang Lab
#
#                                         project_name team_dataset_id  \
# 0  Single-cell transcriptomic and proteomic analy...   sn_rnaseq_pfc
#
#                                      project_dataset  \
# 0  Single nucleus RNA sequencing dataset of PD br...
#
#                                  project_description PI_full_name  \
# 0  We provide an extensive single cell analysis p...     Le Zhang
#
#             PI_email contributor_names submitter_name  ... number_samples  \
# 0  Le.zhang@yale.edu          Le Zhang       Le Zhang  ...             12
#
#         sample_types                             types_of_samples DUA_version  \
# 0  Prefrontal cortex  Late-stage PD and control postmortem brains          NA
#
#                                      metadata_tables             PI_ORCID  \
# 0  ['STUDY', 'PROTOCOL', 'SUBJECT', 'SAMPLE', 'DA...  0000-0002-4860-831X
#
#   PI_google_scholar_id preprocessing_references metadata_version_date  \
# 0                   NA                       NA         v3.0_20241028
#
#   alternate_dataset_id
# 0                   NA
#
# [1 rows x 25 columns]

# %% [markdown]
# ### validate v3 tables

# %%
CDE = CDEv3
for table,df in v3_tables.items():
    schema = CDE[CDE['Table'] == table]

    report = ReportCollector(destination="NA")
    full_table, report = validate_table(df.copy(), table, schema, report)
    report.print_log()
    # should we write validation logs?
# Out:
# recoding number_samples as int
# All required fields are present in *STUDY* table.
# 🚨⚠️❗ **6 Fields with empty (NULL) values:**
#
# 	- other_funding_source: 1/1 empty rows (REQUIRED)
#
# 	- publication_PMID: 1/1 empty rows (REQUIRED)
#
# 	- DUA_version: 1/1 empty rows (REQUIRED)
#
# 	- PI_google_scholar_id: 1/1 empty rows (OPTIONAL)
#
# 	- preprocessing_references: 1/1 empty rows (OPTIONAL)
#
# 	- alternate_dataset_id: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *PROTOCOL* table.
# 🚨⚠️❗ **3 Fields with empty (NULL) values:**
#
# 	- github_url: 1/1 empty rows (REQUIRED)
#
# 	- protocols_io_DOI: 1/1 empty rows (REQUIRED)
#
# 	- other_reference: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *SUBJECT* table.
# 🚨⚠️❗ **1 Fields with empty (NULL) values:**
#
# 	- primary_diagnosis_text: 12/12 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# All required fields are present in *SAMPLE* table.
# 🚨⚠️❗ **15 Fields with empty (NULL) values:**
#
# 	- organism: 12/12 empty rows (REQUIRED)
#
# 	- assay_type: 12/12 empty rows (REQUIRED)
#
# 	- time: 12/12 empty rows (OPTIONAL)
#
# 	- alternate_id: 12/12 empty rows (OPTIONAL)
#
# 	- development_stage_ontology_term_id: 12/12 empty rows (OPTIONAL)
#
# 	- self_reported_ethnicity_ontology_term_id: 12/12 empty rows (OPTIONAL)
#
# 	- disease_ontology_term_id: 12/12 empty rows (OPTIONAL)
#
# 	- tissue_ontology_term_id: 12/12 empty rows (OPTIONAL)
#
# 	- assay_ontology_term_id: 12/12 empty rows (OPTIONAL)
#
# 	- donor_id: 12/12 empty rows (OPTIONAL)
#
# 	- pm_PH: 12/12 empty rows (OPTIONAL)
#
# 	- cell_type_ontology_term_id: 12/12 empty rows (OPTIONAL)
#
# 	- source_RIN: 12/12 empty rows (OPTIONAL)
#
# 	- DV200: 12/12 empty rows (OPTIONAL)
#
# 	- suspension_type: 12/12 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# All required fields are present in *DATA* table.
# 🚨⚠️❗ **4 Fields with empty (NULL) values:**
#
# 	- file_description: 36/36 empty rows (REQUIRED)
#
# 	- header: 36/36 empty rows (OPTIONAL)
#
# 	- annotation: 36/36 empty rows (OPTIONAL)
#
# 	- configuration_file: 36/36 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *PMDBS* table.
# 🚨⚠️❗ **1 Fields with empty (NULL) values:**
#
# 	- hemisphere: 12/12 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding input_cell_count as int
# recoding sequencing_length as int
# All required fields are present in *ASSAY_RNAseq* table.
# 🚨⚠️❗ **1 Fields with empty (NULL) values:**
#
# 	- RIN: 12/12 empty rows (REQUIRED)
# No invalid entries found in Enum fields.
#
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# All required fields are present in *CLINPATH* table.
# 🚨⚠️❗ **46 Fields with empty (NULL) values:**
#
# 	- AMPPD_id: 12/12 empty rows (OPTIONAL)
#
# 	- GP2_id: 12/12 empty rows (OPTIONAL)
#
# 	- family_history: 12/12 empty rows (OPTIONAL)
#
# 	- last_diagnosis: 12/12 empty rows (OPTIONAL)
#
# 	- age_at_onset: 12/12 empty rows (OPTIONAL)
#
# 	- age_at_diagnosis: 12/12 empty rows (OPTIONAL)
#
# 	- first_motor_symptom: 12/12 empty rows (OPTIONAL)
#
# 	- hx_dementia_mci: 12/12 empty rows (OPTIONAL)
#
# 	- hx_melanoma: 12/12 empty rows (OPTIONAL)
#
# 	- education_level: 12/12 empty rows (OPTIONAL)
#
# 	- smoking_status: 12/12 empty rows (OPTIONAL)
#
# 	- smoking_years: 12/12 empty rows (OPTIONAL)
#
# 	- APOE_e4_status: 1/12 empty rows (OPTIONAL)
#
# 	- time_from_baseline: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_dx_main: 6/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_second_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_third_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_fourth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_fifth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_sixth_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_seventh_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_autopsy_eight_dx: 12/12 empty rows (OPTIONAL)
#
# 	- path_year_death: 12/12 empty rows (OPTIONAL)
#
# 	- cause_death: 12/12 empty rows (OPTIONAL)
#
# 	- other_cause_death_1: 12/12 empty rows (OPTIONAL)
#
# 	- other_cause_death_2: 12/12 empty rows (OPTIONAL)
#
# 	- brain_weight: 12/12 empty rows (OPTIONAL)
#
# 	- path_braak_nft: 12/12 empty rows (OPTIONAL)
#
# 	- path_braak_asyn: 12/12 empty rows (OPTIONAL)
#
# 	- path_cerad: 12/12 empty rows (OPTIONAL)
#
# 	- path_thal: 12/12 empty rows (OPTIONAL)
#
# 	- known_pathogenic_mutation: 12/12 empty rows (OPTIONAL)
#
# 	- PD_pathogenic_mutation: 12/12 empty rows (OPTIONAL)
#
# 	- path_mckeith: 12/12 empty rows (OPTIONAL)
#
# 	- sn_neuronal_loss: 12/12 empty rows (OPTIONAL)
#
# 	- path_infarcs: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_ri: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_a: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_b: 12/12 empty rows (OPTIONAL)
#
# 	- path_nia_aa_c: 12/12 empty rows (OPTIONAL)
#
# 	- TDP43: 12/12 empty rows (OPTIONAL)
#
# 	- arteriolosclerosis_severity_scale: 12/12 empty rows (OPTIONAL)
#
# 	- amyloid_angiopathy_severity_scale: 12/12 empty rows (OPTIONAL)
#
# 	- path_ad_level: 12/12 empty rows (OPTIONAL)
#
# 	- dig_slide_avail: 12/12 empty rows (OPTIONAL)
#
# 	- quant_path_avail: 12/12 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *CONDITION* table.
# 🚨⚠️❗ **2 Fields with empty (NULL) values:**
#
# 	- protocol_id: 2/2 empty rows (REQUIRED)
#
# 	- intervention_aux_table: 2/2 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.

# %%
v3_tables['CONDITION']
# Out:
# Field     condition_id intervention_name intervention_id protocol_id  \
# 0      healthy_control      Case-Control         Control          NA
# 1        idiopathic_pd      Case-Control            Case          NA
#
# Field intervention_aux_table
# 0                         NA
# 1                         NA

# %% [markdown]
# v3_tables['CONDITION]

# %%
STUDY = v3_tables['STUDY']
STUDY
# Out:
#   ASAP_team_name ASAP_lab_name  \
# 0    TEAM-HAFLER  Le Zhang Lab
#
#                                         project_name team_dataset_id  \
# 0  Single-cell transcriptomic and proteomic analy...   sn_rnaseq_pfc
#
#                                      project_dataset  \
# 0  Single nucleus RNA sequencing dataset of PD br...
#
#                                  project_description PI_full_name  \
# 0  We provide an extensive single cell analysis p...     Le Zhang
#
#             PI_email contributor_names submitter_name  ... number_samples  \
# 0  Le.zhang@yale.edu          Le Zhang       Le Zhang  ...             12
#
#         sample_types                             types_of_samples DUA_version  \
# 0  Prefrontal cortex  Late-stage PD and control postmortem brains          NA
#
#                                      metadata_tables             PI_ORCID  \
# 0  ['STUDY', 'PROTOCOL', 'SUBJECT', 'SAMPLE', 'DA...  0000-0002-4860-831X
#
#   PI_google_scholar_id preprocessing_references metadata_version_date  \
# 0                   NA                       NA         v3.0_20241028
#
#   alternate_dataset_id
# 0                   NA
#
# [1 rows x 25 columns]

# %%
v3_tables['SAMPLE']['condition_id']
# Out:
# 0     healthy_control
# 1     healthy_control
# 2     healthy_control
# 3     healthy_control
# 4     healthy_control
# 5     healthy_control
# 6       idiopathic_pd
# 7       idiopathic_pd
# 8       idiopathic_pd
# 9       idiopathic_pd
# 10      idiopathic_pd
# 11      idiopathic_pd
# Name: condition_id, dtype: object

# %% [markdown]
# -------------------------
# ## check md5s

# %%
print(team)

source = "pmdbs"

bucket = f"asap-raw-team-{team}-{source}-{dataset_name}"
bucket = f"asap-raw-data-team-{team}" # for now old locations


key_file_path = Path.home() / f"Projects/ASAP/{team}-credentials.json"

res = authenticate_with_service_account(key_file_path)
print(res)
prefix = "fastqs/**/*.gz"
bucket_files_md5 = get_md5_hashes( bucket, prefix)
# Out:
# hafler
# CompletedProcess(args='gcloud auth activate-service-account --key-file=/Users/ergonyc/Projects/ASAP/hafler-credentials.json', returncode=0, stdout='', stderr='Activated service account credentials for: [raw-admin-hafler@dnastack-asap-parkinsons.iam.gserviceaccount.com]\n')
# gsutil -u dnastack-asap-parkinsons hash -h gs://asap-raw-data-team-hafler/fastqs/**/*.gz

# %%
checksum = v3_tables['DATA'][['file_name','file_MD5']]
checksum['check2'] = checksum['file_name'].map(bucket_files_md5)
checksum['check1'] = checksum['file_MD5']

checksum[checksum.check1 != checksum.check2].file_name.to_list()
# Out:
# /var/folders/0z/hvx6j8cn6yj3bqbyq6rtsxm40000gn/T/ipykernel_57365/2789596456.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   checksum['check2'] = checksum['file_name'].map(bucket_files_md5)
# /var/folders/0z/hvx6j8cn6yj3bqbyq6rtsxm40000gn/T/ipykernel_57365/2789596456.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   checksum['check1'] = checksum['file_MD5']
# []

# %%
checksum[checksum.check1 != checksum.check2].file_name.to_list()
#empty means success!!
# Out:
# []

# %% [markdown]
# ## Create metadata package

# %%
export_path = root_path / f"{team}"

create_upload_medadata_package(export_path, v3_tables)

# %%
schema = CDEv3[CDEv3["Table"] == "SAMPLE"]
schema
# Out:
#      Table                                     Field  \
# 40  SAMPLE                                 sample_id
# 41  SAMPLE                                subject_id
# 42  SAMPLE                          source_sample_id
# 43  SAMPLE                                 replicate
# 44  SAMPLE                           replicate_count
# 45  SAMPLE                           repeated_sample
# 46  SAMPLE                                     batch
# 47  SAMPLE                                  organism
# 48  SAMPLE                                    tissue
# 49  SAMPLE                                assay_type
# 50  SAMPLE                              condition_id
# 51  SAMPLE                 organism_ontology_term_id
# 52  SAMPLE                                      time
# 53  SAMPLE                              alternate_id
# 54  SAMPLE        development_stage_ontology_term_id
# 55  SAMPLE                      sex_ontology_term_id
# 56  SAMPLE  self_reported_ethnicity_ontology_term_id
# 57  SAMPLE                  disease_ontology_term_id
# 58  SAMPLE                   tissue_ontology_term_id
# 59  SAMPLE                    assay_ontology_term_id
# 60  SAMPLE                                  donor_id
# 61  SAMPLE                                     pm_PH
# 62  SAMPLE                cell_type_ontology_term_id
# 63  SAMPLE                                source_RIN
# 64  SAMPLE                                     DV200
# 65  SAMPLE                           suspension_type
#
#                                           Description DataType  Required  \
# 40  Sample ID.:   ID of each individual sample use...   String  Required
# 41  Subject ID.:   Can be multiple samples from ea...   String  Required
# 42  Source Sample ID.:   ID provided by Brain bank...   String  Required
# 43  Replicate.:   Indicator for replicates of the ...   String  Required
# 44  Replicate Count.:   Number of replicates of th...  Integer  Required
# 45  Repeated Sample.:   Repeated Sample indicator....  Integer  Required
# 46  Batch.:   Label to enumerate the batch. This w...   String  Required
# 47  Organism.:   Organism of the subject. Currentl...     Enum  Required
# 48  Tissue.:   Type of tissue.  e.g. "Brain" or ot...   String  Required
# 49  Type of Assay. Refers to the ASSAY_* table. Ex...     Enum  Required
# 50                             experimental condition   String  Required
# 51  Organism Ontology Term ID.:   NCBITaxon e.g. 9...     Enum  Required
# 52  Time.:   Time from baseline in days. Units in ...    Float  Optional
# 53  Alternate ID.:  alternate sample identifier. e...   String  Optional
# 54  Development Stage Ontology Term.:   HsapDv if ...   String  Optional
# 55  Sex Ontology Term ID.:   PATO:0000384 for male...     Enum  Optional
# 56  Self Reported Ethnicity Ontology.:   HANCESTRO...   String  Optional
# 57  Disease Ontology Term ID.:   MONDO or PATO:000...   String  Optional
# 58  Tissue Ontology Term ID.:   UBERON. Included f...   String  Optional
# 59  Assay Ontology Term ID.:   EFO. Included for c...   String  Optional
# 60  Donor ID.:   free-text identifier that disting...   String  Optional
# 61  Post-mortem PH.:   PH measured in the tissue. ...    Float  Optional
# 62  Cell Type Ontology Term ID.:   CL. Included fo...   String  Optional
# 63  Source RIN.:  RIN provided by Tissue/Brain/Bio...    Float  Optional
# 64  DV200.:   Value is the percentage of RNA fragm...    Float  Optional
# 65  Suspension Type.:   Cell, nucleus, or na, as c...   String  Optional
#
#                                            Validation  Shared_key
# 40                                                NaN         1.0
# 41                                                NaN         1.0
# 42                                                NaN         1.0
# 43                                                NaN         0.0
# 44                                                NaN         0.0
# 45                                                NaN         0.0
# 46                                                NaN         1.0
# 47             ["Human", "Mouse","Dog","Fly","Other"]         0.0
# 48                                                NaN         0.0
# 49               ['scRNAseq','snRNAseq','bulkRNAseq']         0.0
# 50                                                NaN         0.0
# 51               ["NCBITaxon:9606","NCBITaxon:10090"]         0.0
# 52                                                NaN         0.0
# 53                                                NaN         0.0
# 54                                                NaN         0.0
# 55  ["PATO:0000384 (male)", "PATO:0000383 (female)...         0.0
# 56                                                NaN         0.0
# 57                                                NaN         0.0
# 58                                                NaN         0.0
# 59                                                NaN         0.0
# 60                                                NaN         0.0
# 61                                             (0-14)         0.0
# 62                                                NaN         0.0
# 63                                                NaN         0.0
# 64                                                NaN         0.0
# 65                                                NaN         0.0

# %%
SAMPLE = v3_tables['SAMPLE']
SUBJECT = v3_tables['SUBJECT']
SUBJECT
# Out:
#    subject_id source_subject_id biobank_name     sex  age_at_collection  \
# 0        HC01            hSDG07  NKI/NYUGSOM  Female               81.0
# 1        HC02            hSDG13  NKI/NYUGSOM  Female               65.0
# 2        HC03           hSDG101  NKI/NYUGSOM  Female               72.0
# 3        HC04            hSDG10  NKI/NYUGSOM    Male               70.0
# 4        HC05            hSDG30  NKI/NYUGSOM    Male               63.0
# 5        HC06            hSDG99  NKI/NYUGSOM    Male               69.0
# 6        PD01           hSDG151  NKI/NYUGSOM  Female               81.0
# 7        PD02           hSDG197  NKI/NYUGSOM  Female               72.0
# 8        PD03           hSDG208  NKI/NYUGSOM  Female               77.0
# 9        PD04           hSDG142  NKI/NYUGSOM    Male               79.0
# 10       PD05           hSDG148  NKI/NYUGSOM    Male               96.0
# 11       PD06           hSDG199  NKI/NYUGSOM    Male               86.0
#
#                          race primary_diagnosis primary_diagnosis_text
# 0   Black or African American   Healthy Control                     NA
# 1                       White   Healthy Control                     NA
# 2                       White   Healthy Control                     NA
# 3                       White   Healthy Control                     NA
# 4   Black or African American   Healthy Control                     NA
# 5                       White   Healthy Control                     NA
# 6                       White     Idiopathic PD                     NA
# 7                       White     Idiopathic PD                     NA
# 8                       White     Idiopathic PD                     NA
# 9                       White     Idiopathic PD                     NA
# 10                      White     Idiopathic PD                     NA
# 11                      White     Idiopathic PD                     NA

# %% [markdown]
# ______________
