# %% [markdown]
# ASAP CRN Metadata validation - wave 2
#
# # Team Sulzer. ASAP CRN Metadata validation - wave 2
#
# 13 Oct 2024
# Andy Henrie

# %%
import pandas as pd
from pathlib import Path
import os, sys

sys.path.append(os.path.abspath((os.path.join(os.getcwd(), 'src/crn_utils'))))

from util import read_CDE, NULL, prep_table, read_meta_table, create_metadata_package
from validate import validate_table, ReportCollector
from update_schema import v1_to_v2, v2_to_v3_PMDBS, intervention_typer
from checksums import extract_md5_from_details2, get_md5_hashes 
from bucket_util import authenticate_with_service_account, gsutil_ls, gsutil_cp, gsutil_mv 

# %load_ext autoreload
# %autoreload 2

root_path = Path.home() / ("Projects/ASAP/data/teams")
# Out:
# Streamlit NOT successfully imported

# %% [markdown]
# ## CDEs
# load the relavent CDEs

# %%
schema_version = "v1"
schema_path = Path.home() / "Projects/ASAP/crn-utils/resource/CDE"
CDEv1 = read_CDE(schema_version, local_path=schema_path)
schema_version = "v2.1"
CDEv2 = read_CDE(schema_version, local_path=schema_path)
schema_version = "v3.0"
CDEv3 = read_CDE(schema_version, local_path=schema_path)
# Out:
# metadata_version: ASAP_CDE_v1
# https://docs.google.com/spreadsheets/d/1c0z5KvRELdT2AtQAH2Dus8kwAyyLrR0CROhKOjpU4Vc/gviz/tq?tqx=out:csv&sheet=v1
# /Users/ergonyc/Projects/ASAP/crn-utils/resource/CDE/ASAP_CDE_v1.csv
# read local file
# metadata_version: ASAP_CDE_v2.1
# https://docs.google.com/spreadsheets/d/1c0z5KvRELdT2AtQAH2Dus8kwAyyLrR0CROhKOjpU4Vc/gviz/tq?tqx=out:csv&sheet=v2.1
# /Users/ergonyc/Projects/ASAP/crn-utils/resource/CDE/ASAP_CDE_v2.1.csv
# read local file
# metadata_version: ASAP_CDE_v3.0
# https://docs.google.com/spreadsheets/d/1c0z5KvRELdT2AtQAH2Dus8kwAyyLrR0CROhKOjpU4Vc/gviz/tq?tqx=out:csv&sheet=v3.0
# /Users/ergonyc/Projects/ASAP/crn-utils/resource/CDE/ASAP_CDE_v3.0.csv
# read local file

# %% [markdown]
# ## Load original tables
# These were submitted as v2.1

# %% [markdown]
# ### Team Sulzer

# %%
## convert 
team = "sulzer"
dataset_name = "sn-rnaseq"

metadata_path = root_path / f"{team}/{dataset_name}/metadata"
og_path = metadata_path / "og"


metadata_version = "v2"

METADATA_VERSION_DATE = f"{metadata_version}_{pd.Timestamp.now().strftime('%Y%m%d')}"

# %%
CDE = CDEv2
tables = CDE['Table'].unique()

dfs = {}
for table in tables:
    df = read_meta_table(og_path / f"{table}.csv")
    schema = CDE[CDE['Table'] == table]
    report = ReportCollector(destination="NA")
    full_table, report = validate_table(df.copy(), table, schema, report)
    report.print_log()
    dfs[table] = full_table
    # df.to_csv(v1_path / f"{table}.csv", index=False)
# Out:
# recoding number_of_brain_samples as int
# 🚨⚠️❗ **Missing Required Fields in STUDY: submitter_email**
# 🚨⚠️❗ **Missing Optional Fields in STUDY: alternate_dataset_id**
# 🚨⚠️❗ **8 Fields with empty (NULL) values:**
#
# 	- ASAP_grant_id: 1/1 empty rows (REQUIRED)
#
# 	- other_funding_source: 1/1 empty rows (REQUIRED)
#
# 	- publication_DOI: 1/1 empty rows (REQUIRED)
#
# 	- publication_PMID: 1/1 empty rows (REQUIRED)
#
# 	- PI_ORCHID: 1/1 empty rows (OPTIONAL)
#
# 	- PI_google_scholar_id: 1/1 empty rows (OPTIONAL)
#
# 	- preprocessing_references: 1/1 empty rows (OPTIONAL)
#
# 	- metadata_version_date: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
# 🚨⚠️❗ **Extra field in STUDY: submittor_email**
#
# All required fields are present in *PROTOCOL* table.
# 🚨⚠️❗ **3 Fields with empty (NULL) values:**
#
# 	- github_url: 1/1 empty rows (REQUIRED)
#
# 	- protocols_io_DOI: 1/1 empty rows (REQUIRED)
#
# 	- other_reference: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# All required fields are present in *SUBJECT* table.
# 🚨⚠️❗ **18 Fields with empty (NULL) values:**
#
# 	- AMPPD_id: 46/46 empty rows (REQUIRED)
#
# 	- GP2_id: 46/46 empty rows (REQUIRED)
#
# 	- race: 28/46 empty rows (REQUIRED)
#
# 	- ethnicity: 23/46 empty rows (REQUIRED)
#
# 	- family_history: 46/46 empty rows (REQUIRED)
#
# 	- age_at_onset: 46/46 empty rows (REQUIRED)
#
# 	- age_at_diagnosis: 46/46 empty rows (REQUIRED)
#
# 	- first_motor_symptom: 46/46 empty rows (REQUIRED)
#
# 	- hx_dementia_mci: 46/46 empty rows (REQUIRED)
#
# 	- hx_melanoma: 46/46 empty rows (REQUIRED)
#
# 	- education_level: 46/46 empty rows (REQUIRED)
#
# 	- smoking_status: 46/46 empty rows (REQUIRED)
#
# 	- smoking_years: 46/46 empty rows (OPTIONAL)
#
# 	- APOE_e4_status: 46/46 empty rows (REQUIRED)
#
# 	- cognitive_status: 46/46 empty rows (REQUIRED)
#
# 	- time_from_baseline: 46/46 empty rows (REQUIRED)
#
# 	- primary_diagnosis: 46/46 empty rows (REQUIRED)
#
# 	- primary_diagnosis_text: 46/46 empty rows (OPTIONAL)
# 🚨⚠️❗ **2 Fields with invalid entries:**
# - _*sex*_:  invalid values 💩'M', 'F'
#     - valid ➡️ 'Male', 'Female', 'Intersex', 'Unnown', 'NA'
# - _*age_at_collection*_:  invalid values 💩'77', '89+ ', '79', '88', '83', '78', '87', '75', '86', '85', '68', '73', '80', '72', '71', '50', '74', '81', '70', '66', '62'
#     - valid ➡️ float or NULL ('NA')
#
# All required fields are present in *CLINPATH* table.
# 🚨⚠️❗ **28 Fields with empty (NULL) values:**
#
# 	- path_autopsy_second_dx: 44/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_third_dx: 30/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_fourth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_fifth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_sixth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_seventh_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_eight_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_year_death: 46/46 empty rows (REQUIRED)
#
# 	- cause_death: 46/46 empty rows (REQUIRED)
#
# 	- other_cause_death_1: 46/46 empty rows (OPTIONAL)
#
# 	- other_cause_death_2: 46/46 empty rows (OPTIONAL)
#
# 	- brain_weight: 46/46 empty rows (REQUIRED)
#
# 	- path_braak_nft: 1/46 empty rows (REQUIRED)
#
# 	- path_cerad: 19/46 empty rows (REQUIRED)
#
# 	- path_thal: 46/46 empty rows (REQUIRED)
#
# 	- known_pathogenic_mutation: 46/46 empty rows (OPTIONAL)
#
# 	- PD_pathogenic_mutation: 46/46 empty rows (OPTIONAL)
#
# 	- path_mckeith: 46/46 empty rows (OPTIONAL)
#
# 	- sn_neuronal_loss: 46/46 empty rows (OPTIONAL)
#
# 	- path_infarcs: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_ri: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_a: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_b: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_c: 46/46 empty rows (OPTIONAL)
#
# 	- TDP43: 46/46 empty rows (OPTIONAL)
#
# 	- arteriolosclerosis_severity_scale: 46/46 empty rows (OPTIONAL)
#
# 	- amyloid_angiopathy_severity_scale: 46/46 empty rows (OPTIONAL)
#
# 	- path_ad_level: 46/46 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# recoding input_cell_count as int
# All required fields are present in *SAMPLE* table.
# 🚨⚠️❗ **Missing Optional Fields in SAMPLE: alternate_sample_id**
# 🚨⚠️❗ **12 Fields with empty (NULL) values:**
#
# 	- hemisphere: 46/46 empty rows (REQUIRED)
#
# 	- region_level_2: 18/46 empty rows (REQUIRED)
#
# 	- RIN: 28/46 empty rows (REQUIRED)
#
# 	- source_RIN: 46/46 empty rows (REQUIRED)
#
# 	- input_cell_count: 28/46 empty rows (REQUIRED)
#
# 	- self_reported_ethnicity_ontology_term_id: 46/46 empty rows (REQUIRED)
#
# 	- disease_ontology_term_id: 46/46 empty rows (REQUIRED)
#
# 	- cell_type_ontology_term_id: 46/46 empty rows (REQUIRED)
#
# 	- assay_ontology_term_id: 46/46 empty rows (REQUIRED)
#
# 	- DV200: 46/46 empty rows (OPTIONAL)
#
# 	- pm_PH: 46/46 empty rows (OPTIONAL)
#
# 	- donor_id: 46/46 empty rows (OPTIONAL)
# 🚨⚠️❗ **4 Fields with invalid entries:**
# - _*region_level_2*_:  invalid values 💩'Substantia Nigra'
#     - valid ➡️ 'Prefrontal cortex', 'Superior frontal gyrus', 'Middle frontal gyrus', 'Inferior frontal gyrus', 'Superior temporal gyrus', 'Middle temporal gyrus', 'Inferior temporal gyrus', 'Fusiform gyrus', 'Transentorhinal region', 'Entorinal region', 'Subiculum', 'CA1-CA4', 'Amygdala', 'Periamygdala cortex', 'Anterior cingulate gyrus', 'Posterior cingulate gyrus', 'Superior parietal lobule', 'Inferior parietal lobule', 'Parastriate cortex', 'Peristriate cortex', 'Striate cortex', 'Insular cortex', 'Caudate nucleus', 'Putamen', 'Globus pallidus', 'Thalamus', 'Subthalamic nucleus', 'Substantia nigra', 'Pontine tegmentum', 'Pontine base', 'Medulla tegmentum', 'Medulla base', 'Cerebellar vermis', 'Cerebellar hemisphere', 'Dentate nucleus', 'Right colon', 'Left colon', 'Unknown', 'NA'
# - _*molecular_source*_:  invalid values 💩'RNA'
#     - valid ➡️ 'Total RNA', 'PolyA RNA', 'Cytoplasmic RNA', 'Nuclear RNA', 'Genomic DNA', 'Protein', 'Other', 'NA'
# - _*input_cell_count*_:  invalid values 💩'915.1258 ng', '1411.8474 ng', '1608.6002 ng', '704.4034 ng', '1444.6272 ng', '896.3852 ng', '2392.286 ng', '714.5692 ng', '923.9646 ng', '866.4158 ng', '1420.8972 ng', '2169.106 ng', '1069.3564 ng', '1192.589 ng', '1008.9174 ng', '983.9328 ng', '1266.1952 ng', '945.216 ng', 'NA'
#     - valid ➡️ int or NULL ('NA')
# - _*organism_ontology_term_id*_:  invalid values 💩'NCBITaxon:9607', 'NCBITaxon:9608', 'NCBITaxon:9609', 'NCBITaxon:9610', 'NCBITaxon:9611', 'NCBITaxon:9612', 'NCBITaxon:9613', 'NCBITaxon:9614', 'NCBITaxon:9615', 'NCBITaxon:9616', 'NCBITaxon:9617', 'NCBITaxon:9618', 'NCBITaxon:9619', 'NCBITaxon:9620', 'NCBITaxon:9621', 'NCBITaxon:9622', 'NCBITaxon:9623', 'NCBITaxon:9624', 'NCBITaxon:9625', 'NCBITaxon:9626', 'NCBITaxon:9627', 'NCBITaxon:9628', 'NCBITaxon:9629', 'NCBITaxon:9630', 'NCBITaxon:9631', 'NCBITaxon:9632', 'NCBITaxon:9633', 'NCBITaxon:9634', 'NCBITaxon:9635', 'NCBITaxon:9636', 'NCBITaxon:9637', 'NCBITaxon:9638', 'NCBITaxon:9639', 'NCBITaxon:9640', 'NCBITaxon:9641', 'NCBITaxon:9642', 'NCBITaxon:9643', 'NCBITaxon:9644', 'NCBITaxon:9645', 'NCBITaxon:9646', 'NCBITaxon:9647', 'NCBITaxon:9648', 'NCBITaxon:9649', 'NCBITaxon:9650', 'NCBITaxon:9651'
#     - valid ➡️ 'NCBITaxon:9606', 'NA'
#
# recoding replicate_count as int
# recoding repeated_sample as int
# All required fields are present in *DATA* table.
# 🚨⚠️❗ **7 Fields with empty (NULL) values:**
#
# 	- file_name: 46/46 empty rows (REQUIRED)
#
# 	- file_description: 46/46 empty rows (REQUIRED)
#
# 	- file_MD5: 46/46 empty rows (REQUIRED)
#
# 	- time: 46/46 empty rows (REQUIRED)
#
# 	- header: 46/46 empty rows (REQUIRED)
#
# 	- annotation: 46/46 empty rows (REQUIRED)
#
# 	- configuration_file: 46/46 empty rows (REQUIRED)
# 🚨⚠️❗ **1 Fields with invalid entries:**
# - _*technology*_:  invalid values 💩'sN'
#     - valid ➡️ 'SN', 'SC', 'Spatial', 'Bulk', 'Seq', 'Array', 'NA'

# %%
SUBJECT = read_meta_table(og_path / "SUBJECT.csv")
CLINPATH = read_meta_table(og_path / "CLINPATH.csv")
STUDY = read_meta_table(og_path / "STUDY.csv")
PROTOCOL = read_meta_table(og_path / "PROTOCOL.csv")
SAMPLE = read_meta_table(og_path / "SAMPLE.csv")
DATA = read_meta_table(og_path / "DATA.csv")

# %%
STUDY['metadata_version_date'] = METADATA_VERSION_DATE
STUDY.rename(columns={"submittor_email":"submitter_email"}, inplace=True)
STUDY['alternate_dataset_id'] = NULL
STUDY['team_dataset_id'] = dataset_name.replace(" ", "_").replace("-", "_")

# %%
SUBJECT = prep_table(SUBJECT, CDE)
SUBJECT['sex'] = SUBJECT['sex'].replace({"M":"Male", "F":"Female"})
SUBJECT.head()
# Out:
#   subject_id source_subject_id AMPPD_id GP2_id         biobank_name organism  \
# 0        OJ9            T-4530       NA     NA  New York Brain Bank    Human
# 1        OJ8            T-4105       NA     NA  New York Brain Bank    Human
# 2        OJ7            T-5259       NA     NA  New York Brain Bank    Human
# 3        OJ6            T-5385       NA     NA  New York Brain Bank    Human
# 4        OJ5            T-2465       NA     NA  New York Brain Bank    Human
#
#       sex age_at_collection                       race  \
# 0    Male                77                    Unknown
# 1  Female              89+                     Unknown
# 2    Male                79                      White
# 3    Male                88                      White
# 4  Female                83  Black or African American
#
#                 ethnicity  ... hx_dementia_mci hx_melanoma education_level  \
# 0                 Unknown  ...         Unknown     Unknown         Unknown
# 1      Hispanic or Latino  ...         Unknown     Unknown         Unknown
# 2  Not Hispanic or Latino  ...         Unknown     Unknown         Unknown
# 3  Not Hispanic or Latino  ...         Unknown     Unknown         Unknown
# 4  Not Hispanic or Latino  ...         Unknown     Unknown         Unknown
#
#   smoking_status smoking_years APOE_e4_status cognitive_status  \
# 0        Unknown       Unknown        Unknown          Unknown
# 1        Unknown       Unknown        Unknown          Unknown
# 2        Unknown       Unknown        Unknown          Unknown
# 3        Unknown       Unknown        Unknown          Unknown
# 4        Unknown       Unknown        Unknown          Unknown
#
#   time_from_baseline primary_diagnosis primary_diagnosis_text
# 0            Unknown           Unknown                Unknown
# 1            Unknown           Unknown                Unknown
# 2            Unknown           Unknown                Unknown
# 3            Unknown           Unknown                Unknown
# 4            Unknown           Unknown                Unknown
#
# [5 rows x 25 columns]

# %%
SUBJECT['subject_id'].shape
# Out:
# (46,)

# %%
SUBJECT['source_subject_id'].unique()
# Out:
# array(['T-4530', 'T-4105', 'T-5259', 'T-5385', 'T-2465', 'T-3799',
#        'T-4424', 'T-5133', 'T-5227', 'T-5547', 'T-5359', 'T-4116',
#        'T-4839', 'T-2007', 'T-4938', 'T-5498', 'T-2791', 'T-4695',
#        'T-4934', 'T-3870', 'T-124', 'T-81', 'T-4515', 'T-4235', 'T-4815',
#        'T-4857', 'T-3998', 'T-4462', 'T-4108', 'T-4174', 'T3860',
#        'T-4162', 'T-4210', 'T-233', 'T1976', 'T-2017', 'T-308', 'T-1952',
#        'T-777', 'T-1619', 'T290', 'T-551', 'T-257', 'T-343', 'T-362'],
#       dtype=object)

# %%
SUBJECT['hx_dementia_mci'] = SUBJECT['hx_dementia_mci'].replace("Unknown", NULL)

SUBJECT['hx_melanoma'] = SUBJECT['hx_melanoma'].replace("Unknown", NULL)
SUBJECT['education_level'] = SUBJECT['education_level'].replace("Unknown", NULL)
SUBJECT['cognitive_status'] = SUBJECT['cognitive_status'].replace("Unknown", NULL)
SUBJECT['primary_diagnosis'] = SUBJECT['primary_diagnosis'].replace("Unknown", NULL)

# %%
SAMPLE = prep_table(SAMPLE, CDE)

SAMPLE["organism_ontology_term_id"] = "NCBITaxon:9606"
SAMPLE['molecular_source'] = SAMPLE['molecular_source'].replace("RNA", "PolyA RNA")
SAMPLE['region_level_2'] = SAMPLE['region_level_2'].replace('Substantia Nigra', 'Substantia nigra',)
SAMPLE.head()
# Out:
#   sample_id subject_id source_sample_id replicate replicate_count  \
# 0     T-362      OF001            T-362      Rep1               1
# 1     T-308      OF009            T-308      Rep1               1
# 2     T3860      OF016            T3860      Rep1               1
# 3      T290      OF005             T290      Rep1               1
# 4     T-233      OF013            T-233      Rep1               1
#
#   repeated_sample batch tissue      brain_region hemisphere  ...  \
# 0               0     1  Brain  Cingulate Cortex         NA  ...
# 1               0     1  Brain  Cingulate Cortex         NA  ...
# 2               0     1  Brain  Cingulate Cortex         NA  ...
# 3               0     1  Brain  Cingulate Cortex         NA  ...
# 4               0     1  Brain  Cingulate Cortex         NA  ...
#
#     sex_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0  PATO:0000383 (female)                                  Unknown
# 1    PATO:0000384 (male)                                  Unknown
# 2    PATO:0000384 (male)                                  Unknown
# 3    PATO:0000384 (male)                                  Unknown
# 4    PATO:0000384 (male)                                  Unknown
#
#   disease_ontology_term_id tissue_ontology_term_id cell_type_ontology_term_id  \
# 0                       NA          UBERON:0003027                         NA
# 1                       NA          UBERON:0003027                         NA
# 2                       NA          UBERON:0003027                         NA
# 3                       NA          UBERON:0003027                         NA
# 4                       NA          UBERON:0003027                         NA
#
#   assay_ontology_term_id suspension_type DV200 pm_PH donor_id
# 0                     NA         Nucleus    NA    NA       NA
# 1                     NA         Nucleus    NA    NA       NA
# 2                     NA         Nucleus    NA    NA       NA
# 3                     NA         Nucleus    NA    NA       NA
# 4                     NA         Nucleus    NA    NA       NA
#
# [5 rows x 33 columns]

# %%
fix_samples = {'T3860':'T-3860', 'T290':'T-290','T1976':'T-1976'}
SAMPLE['sample_id'] = SAMPLE['sample_id'].replace(fix_samples)
SAMPLE['source_sample_id'] = SAMPLE['source_sample_id'].replace(fix_samples)
SAMPLE.head()
# Out:
#   sample_id subject_id source_sample_id replicate replicate_count  \
# 0     T-362      OF001            T-362      Rep1               1
# 1     T-308      OF009            T-308      Rep1               1
# 2    T-3860      OF016           T-3860      Rep1               1
# 3     T-290      OF005            T-290      Rep1               1
# 4     T-233      OF013            T-233      Rep1               1
#
#   repeated_sample batch tissue      brain_region hemisphere  ...  \
# 0               0     1  Brain  Cingulate Cortex         NA  ...
# 1               0     1  Brain  Cingulate Cortex         NA  ...
# 2               0     1  Brain  Cingulate Cortex         NA  ...
# 3               0     1  Brain  Cingulate Cortex         NA  ...
# 4               0     1  Brain  Cingulate Cortex         NA  ...
#
#     sex_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0  PATO:0000383 (female)                                  Unknown
# 1    PATO:0000384 (male)                                  Unknown
# 2    PATO:0000384 (male)                                  Unknown
# 3    PATO:0000384 (male)                                  Unknown
# 4    PATO:0000384 (male)                                  Unknown
#
#   disease_ontology_term_id tissue_ontology_term_id cell_type_ontology_term_id  \
# 0                       NA          UBERON:0003027                         NA
# 1                       NA          UBERON:0003027                         NA
# 2                       NA          UBERON:0003027                         NA
# 3                       NA          UBERON:0003027                         NA
# 4                       NA          UBERON:0003027                         NA
#
#   assay_ontology_term_id suspension_type DV200 pm_PH donor_id
# 0                     NA         Nucleus    NA    NA       NA
# 1                     NA         Nucleus    NA    NA       NA
# 2                     NA         Nucleus    NA    NA       NA
# 3                     NA         Nucleus    NA    NA       NA
# 4                     NA         Nucleus    NA    NA       NA
#
# [5 rows x 33 columns]

# %%
batch_mapper = {"Cingulate Cortex":"cing1", "Substantia Nigra": "sn1"}
SAMPLE['batch']=SAMPLE['brain_region'].map(batch_mapper)

# %% [markdown]
# ## 🚨⚠️❗ EXTREME CURATION HERE 🚨⚠️❗
# The codeing by Team-Sulzer is inconsistent.  However I am able to infer the following:
#
# TODO:  Define `sample_id`s from `subject_id`, and create `sample_id` as `source_subject_id`
#
#
# `source_subject_id`s seem to be unique and correct.  Although the CLINPATH.duration_pmi are different for `source_subject_id`="T-2465", and some demographic info is missing for the cingulate sample, these seem to be two samples from the same subject.
#
# Hence:  We will assume `source_subject_id` is ground truth.   Redefine `sample_id` from the current `subject_id` (which matches file naming conventsions), and  create a _new_ `subject_id` from the `source_subject_id` by prepending "SUL_".  Finally, `source_sample_id` will be set to pd.NA as is currently just a copy of `source_subject_id`

# %% [markdown]
# ### fix SAMPLE table first

# %%
# simple copy subject_id to sample_id, sample_id == source_sample_id
SAMPLE['sample_id'] = SAMPLE['subject_id']

# %%
fix_samples = {'T3860':'T-3860', 'T290':'T-290','T1976':'T-1976'}
SAMPLE['source_sample_id'] = SAMPLE['source_sample_id'].replace(fix_samples)
# then make a subject_id by copying souce_sample_id
SAMPLE['subject_id'] = "SUL_" + SAMPLE['source_sample_id'].str.replace("-","_")

# # finally set source_sample_id to pd.NA
SAMPLE['source_sample_id'] = NULL

SAMPLE['alternate_sample_id'] = NULL

SAMPLE.head()
# Out:
#   sample_id  subject_id source_sample_id replicate replicate_count  \
# 0     OF001   SUL_T_362               NA      Rep1               1
# 1     OF009   SUL_T_308               NA      Rep1               1
# 2     OF016  SUL_T_3860               NA      Rep1               1
# 3     OF005   SUL_T_290               NA      Rep1               1
# 4     OF013   SUL_T_233               NA      Rep1               1
#
#   repeated_sample  batch tissue      brain_region hemisphere  ...  \
# 0               0  cing1  Brain  Cingulate Cortex         NA  ...
# 1               0  cing1  Brain  Cingulate Cortex         NA  ...
# 2               0  cing1  Brain  Cingulate Cortex         NA  ...
# 3               0  cing1  Brain  Cingulate Cortex         NA  ...
# 4               0  cing1  Brain  Cingulate Cortex         NA  ...
#
#   self_reported_ethnicity_ontology_term_id disease_ontology_term_id  \
# 0                                  Unknown                       NA
# 1                                  Unknown                       NA
# 2                                  Unknown                       NA
# 3                                  Unknown                       NA
# 4                                  Unknown                       NA
#
#   tissue_ontology_term_id cell_type_ontology_term_id assay_ontology_term_id  \
# 0          UBERON:0003027                         NA                     NA
# 1          UBERON:0003027                         NA                     NA
# 2          UBERON:0003027                         NA                     NA
# 3          UBERON:0003027                         NA                     NA
# 4          UBERON:0003027                         NA                     NA
#
#   suspension_type DV200 pm_PH donor_id alternate_sample_id
# 0         Nucleus    NA    NA       NA                  NA
# 1         Nucleus    NA    NA       NA                  NA
# 2         Nucleus    NA    NA       NA                  NA
# 3         Nucleus    NA    NA       NA                  NA
# 4         Nucleus    NA    NA       NA                  NA
#
# [5 rows x 34 columns]

# %% [markdown]
# ### now SUBJECT table

# %%
fix_samples = {'T3860':'T-3860', 'T290':'T-290','T1976':'T-1976'}
SUBJECT['source_subject_id'] = SUBJECT['source_subject_id'].replace(fix_samples)

SUBJECT['subject_id'] = "SUL_" + SUBJECT['source_subject_id'].str.replace("-","_")
SUBJECT['subject_id'].unique()
# Out:
# array(['SUL_T_4530', 'SUL_T_4105', 'SUL_T_5259', 'SUL_T_5385',
#        'SUL_T_2465', 'SUL_T_3799', 'SUL_T_4424', 'SUL_T_5133',
#        'SUL_T_5227', 'SUL_T_5547', 'SUL_T_5359', 'SUL_T_4116',
#        'SUL_T_4839', 'SUL_T_2007', 'SUL_T_4938', 'SUL_T_5498',
#        'SUL_T_2791', 'SUL_T_4695', 'SUL_T_4934', 'SUL_T_3870',
#        'SUL_T_124', 'SUL_T_81', 'SUL_T_4515', 'SUL_T_4235', 'SUL_T_4815',
#        'SUL_T_4857', 'SUL_T_3998', 'SUL_T_4462', 'SUL_T_4108',
#        'SUL_T_4174', 'SUL_T_3860', 'SUL_T_4162', 'SUL_T_4210',
#        'SUL_T_233', 'SUL_T_1976', 'SUL_T_2017', 'SUL_T_308', 'SUL_T_1952',
#        'SUL_T_777', 'SUL_T_1619', 'SUL_T_290', 'SUL_T_551', 'SUL_T_257',
#        'SUL_T_343', 'SUL_T_362'], dtype=object)

# %% [markdown]
# ### and CLINPATH table is already coded as it should be

# %%
fix_samples = {'T3860':'T-3860', 'T290':'T-290','T1976':'T-1976'}
CLINPATH['source_subject_id'] = CLINPATH['source_subject_id'].replace(fix_samples)
CLINPATH['source_subject_id'].unique()
# Out:
# array(['T-4530', 'T-4105', 'T-5259', 'T-5385', 'T-2465', 'T-3799',
#        'T-4424', 'T-5133', 'T-5227', 'T-5547', 'T-5359', 'T-4116',
#        'T-4839', 'T-2007', 'T-4938', 'T-5498', 'T-2791', 'T-4695',
#        'T-4934', 'T-3870', 'T-124', 'T-81', 'T-4515', 'T-4235', 'T-4815',
#        'T-4857', 'T-3998', 'T-4462', 'T-4108', 'T-4174', 'T-3860',
#        'T-4162', 'T-4210', 'T-233', 'T-1976', 'T-2017', 'T-308', 'T-1952',
#        'T-777', 'T-1619', 'T-290', 'T-551', 'T-257', 'T-343', 'T-362'],
#       dtype=object)

# %%
CLINPATH['subject_id'] = "SUL_" + CLINPATH['source_subject_id'].str.replace("-","_")
CLINPATH.head()
# Out:
#    subject_id source_subject_id duration_pmi  \
# 0  SUL_T_4530            T-4530  17.06666667
# 1  SUL_T_4105            T-4105           20
# 2  SUL_T_5259            T-5259         10.5
# 3  SUL_T_5385            T-5385        14.05
# 4  SUL_T_2465            T-2465         9.25
#
#                                 path_autopsy_dx_main path_autopsy_second_dx  \
# 0                  Parkinson's disease with dementia                     NA
# 1  Alzheimer's disease (intermediate level neurop...                     NA
# 2                  Parkinson's disease with dementia                     NA
# 3      Control, Primary age-related tauopathy (PART)                     NA
# 4     Control, Low level AD neuropathological change                     NA
#
#   path_autopsy_third_dx path_autopsy_fourth_dx path_autopsy_fifth_dx  \
# 0                    NA                     NA                    NA
# 1                    NA                     NA                    NA
# 2                    NA                     NA                    NA
# 3                    NA                     NA                    NA
# 4                    NA                     NA                    NA
#
#   path_autopsy_sixth_dx path_autopsy_seventh_dx  ... path_nia_ri  \
# 0                    NA                      NA  ...          NA
# 1                    NA                      NA  ...          NA
# 2                    NA                      NA  ...          NA
# 3                    NA                      NA  ...          NA
# 4                    NA                      NA  ...          NA
#
#   path_nia_aa_a path_nia_aa_b path_nia_aa_c TDP43  \
# 0            NA            NA            NA    NA
# 1            NA            NA            NA    NA
# 2            NA            NA            NA    NA
# 3            NA            NA            NA    NA
# 4            NA            NA            NA    NA
#
#   arteriolosclerosis_severity_scale amyloid_angiopathy_severity_scale  \
# 0                                NA                                NA
# 1                                NA                                NA
# 2                                NA                                NA
# 3                                NA                                NA
# 4                                NA                                NA
#
#   path_ad_level dig_slide_avail quant_path_avail
# 0            NA              No               No
# 1            NA              No               No
# 2            NA              No               No
# 3            NA              No               No
# 4            NA              No               No
#
# [5 rows x 36 columns]

# %% [markdown]
# ## DATA table
#
# The DATA.csv was not filled out.  So we will construct it by joining the manifest from the source of data transfer for Team Sulzer.
#
# ### read_file_list
# Helper function to read sulzer manifest

# %%
cingulate_files = Path.home() / "Projects/ASAP/team-sulzer/cingulate_manifest.txt"
nigra_files = Path.home() / "Projects/ASAP/team-sulzer/nigra_manifest.txt"

# %%
# tmp2 = pd.read_csv("sulzer_fastqs.txt", delimiter=" ", header=None, names=['file_name'])
def read_gz_file_list(file_nm):
    # Read the text file
    with open(file_nm, 'r') as file:
        lines = [line.strip() for line in file]

    # Create a DataFrame
    df = pd.DataFrame(lines, columns=['file_name'])

    df['parts'] = df['file_name'].apply(lambda x: x.lstrip("gs://").split("/"))
    df['source'] = df['parts'].apply(lambda x: x[1].lstrip("fastqs_") )
    df['name'] = df['parts'].apply(lambda x: x[-1])

    df['name_parts'] = df['name'].apply(lambda x: x.rstrip('.fastq.gz').split("_"))
    df['sample_id'] = df['name_parts'].apply(lambda x: x[0])
    df['lane_id'] = df['name_parts'].apply(lambda x: x[2])
    df['file_type'] = df['name_parts'].apply(lambda x: x[3])
    df.drop(columns=['parts','name_parts'], inplace=True)
    return df

# tmp2 = pd.read_csv("sulzer_fastqs.txt", delimiter=" ", header=None, names=['file_name'])
def read_file_list_sulzer(file_nm):
    # Read the text file
    keep_ends = ("fastq.gz", "bam", "tar")
    with open(file_nm, 'r') as file:
        lines = [line.strip() for line in file if line.strip().endswith(keep_ends)]

    # Create a DataFrame
    df = pd.DataFrame(lines, columns=['file_name'])

    df['parts'] = df['file_name'].apply(lambda x: x.split("/"))
    # df['source'] = df['parts'].apply(lambda x: x[5].lstrip("fastqs_") )
    df['file_name'] = df['parts'].apply(lambda x: x[-1])
    df['sample_id'] = df['parts'].apply(lambda x: x[6] if x[-1].endswith(("fastq.gz","tar")) else x[7])
    df['file_type'] = df['parts'].apply(lambda x: x[7] if x[7].strip() in ["fastq","analysis"] else "bam")
    # df['tmp1'] = df['parts'].apply(lambda x: x[7] if len(x) > 7 else pd.NA)

    # df['name_parts'] = df['name'].apply(lambda x: x.rstrip('.fastq.gz').split("_"))
    # df['sample_id'] = df['name_parts'].apply(lambda x: x[0])
    # df['lane_id'] = df['name_parts'].apply(lambda x: x[2])
    # df['file_type'] = df['name_parts'].apply(lambda x: x[3])
    df.drop(columns=['parts'], inplace=True)
    return df

# %%
c_fastqs = read_file_list_sulzer(cingulate_files)
c_fastqs['src'] = "cingulate"
n_fastqs = read_file_list_sulzer(nigra_files)
n_fastqs['src'] = "nigra"

from_source = pd.concat([c_fastqs, n_fastqs])

# %%
n_fastqs
# Out:
#                          file_name sample_id file_type    src
# 0    OJ1_cellranger_count_outs.tar       OJ1  analysis  nigra
# 1      OJ1_S1_L001_I1_001.fastq.gz       OJ1     fastq  nigra
# 2      OJ1_S1_L001_I2_001.fastq.gz       OJ1     fastq  nigra
# 3      OJ1_S1_L001_R1_001.fastq.gz       OJ1     fastq  nigra
# 4      OJ1_S1_L001_R2_001.fastq.gz       OJ1     fastq  nigra
# ..                             ...       ...       ...    ...
# 454    OJ9_S1_L003_R2_001.fastq.gz       OJ9     fastq  nigra
# 455    OJ9_S1_L004_I1_001.fastq.gz       OJ9     fastq  nigra
# 456    OJ9_S1_L004_I2_001.fastq.gz       OJ9     fastq  nigra
# 457    OJ9_S1_L004_R1_001.fastq.gz       OJ9     fastq  nigra
# 458    OJ9_S1_L004_R2_001.fastq.gz       OJ9     fastq  nigra
#
# [459 rows x 4 columns]

# %%
## now make DATA from scratch to ready to join into
# Start with sample_id
# DATA_ = read_meta_table(metadata_path / "DATA.csv")

DATA = SAMPLE[["sample_id", "replicate", "replicate_count","repeated_sample","batch"]].copy()

DATA.head()
# Out:
#   sample_id replicate replicate_count repeated_sample  batch
# 0     OF001      Rep1               1               0  cing1
# 1     OF009      Rep1               1               0  cing1
# 2     OF016      Rep1               1               0  cing1
# 3     OF005      Rep1               1               0  cing1
# 4     OF013      Rep1               1               0  cing1

# %%
DATA = pd.merge(DATA, from_source, on='sample_id', how='left')
DATA.tail()
# Out:
#     sample_id replicate replicate_count repeated_sample batch  \
# 707      OJ26      Rep1               1               0   sn1
# 708      OJ26      Rep1               1               0   sn1
# 709      OJ26      Rep1               1               0   sn1
# 710      OJ26      Rep1               1               0   sn1
# 711      OJ26      Rep1               1               0   sn1
#
#                         file_name file_type    src
# 707  OJ26_S1_L003_R2_001.fastq.gz     fastq  nigra
# 708  OJ26_S1_L004_I1_001.fastq.gz     fastq  nigra
# 709  OJ26_S1_L004_I2_001.fastq.gz     fastq  nigra
# 710  OJ26_S1_L004_R1_001.fastq.gz     fastq  nigra
# 711  OJ26_S1_L004_R2_001.fastq.gz     fastq  nigra

# %%
DATA['omic'] = 'RNA'
DATA['adjustments'] = 'Raw'
DATA['technology'] = "SN"
DATA['file_description']= DATA['file_type'].map({"bam": "Binary aligned sequence",
                                                "fastq": "gzip fastq",
                                                "analysis": "cellranger counts tar archive"})
DATA['file_description']= DATA['file_type'].map({"bam": "Reads",
                                                "fastq": "Reads",
                                                "analysis": "Counts"})

# now fix the file_type
DATA['file_type'] = DATA['file_type'].replace({'fastq':'fastq', "bam":'Per sample raw file', "analysis":'Per sample processed file'})
DATA['content'] = 'Counts'

# %% [markdown]
# get "md5s"

# %%
cingulate_md5s = Path.home() / "Projects/ASAP/team-sulzer/cingulate_fastq_md5.log"
nigra_md5s = Path.home() / "Projects/ASAP/team-sulzer/nigra_fastq_md5.log"

# %%
from checksums import extract_hashes_from_gsutil

# cingulate
cingulate_hashs = extract_hashes_from_gsutil(cingulate_md5s)

# nigra
nigra_hashs = extract_hashes_from_gsutil(nigra_md5s)

# combine cingulate and nigra
source_file_crc = cingulate_hashs[0] | nigra_hashs[0]
source_file_md5 = cingulate_hashs[1] | nigra_hashs[1]

# %%
DATA['file_MD5'] = DATA['file_name'].map(source_file_md5)

# %%
DATA.head()
# Out:
#   sample_id replicate replicate_count repeated_sample  batch  \
# 0     OF001      Rep1               1               0  cing1
# 1     OF001      Rep1               1               0  cing1
# 2     OF001      Rep1               1               0  cing1
# 3     OF001      Rep1               1               0  cing1
# 4     OF001      Rep1               1               0  cing1
#
#                          file_name                  file_type        src omic  \
# 0         possorted_genome_bam.bam        Per sample raw file  cingulate  RNA
# 1  OF001_cellranger_count_outs.tar  Per sample processed file  cingulate  RNA
# 2    OF001_S1_L001_I1_001.fastq.gz                      fastq  cingulate  RNA
# 3    OF001_S1_L001_I2_001.fastq.gz                      fastq  cingulate  RNA
# 4    OF001_S1_L001_R1_001.fastq.gz                      fastq  cingulate  RNA
#
#   adjustments technology file_description content  \
# 0         Raw         SN            Reads  Counts
# 1         Raw         SN           Counts  Counts
# 2         Raw         SN            Reads  Counts
# 3         Raw         SN            Reads  Counts
# 4         Raw         SN            Reads  Counts
#
#                            file_MD5
# 0                               NaN
# 1                               NaN
# 2  74a74c8929b01a6da7e79b83f91a6607
# 3  644d95728b50f1ff9db7becfa5b5c394
# 4  129dfb6fe6115966e2cf2af5e3c82bdf

# %% [markdown]
# # No data found for `OJ8`!!!

# %% [markdown]
# # load manifests and md5s
#
# Separate manifests for cingulate and nigra to make it easier for Team Sulzer to collect.

# %%
SAMPLE[SAMPLE['sample_id']=='OJ8']
empty_sample = SAMPLE['sample_id']=='OJ8'
print(SAMPLE.shape)
SAMPLE = SAMPLE[~empty_sample]
SAMPLE.shape
# Out:
# (46, 34)
# (45, 34)

# %%
DATA[DATA['sample_id']=='OJ8']
empty_sample = DATA['sample_id']=='OJ8'
print(DATA.shape)
DATA = DATA[~empty_sample]
DATA.shape
# Out:
# (712, 14)
# (711, 14)

# %%
DATA.rename(columns={'adjustments':'adjustment'}, inplace=True)
DATA['time'] = NULL
DATA['header'] = NULL
DATA['annotation'] = NULL
DATA['configuration_file'] = NULL

DATA.head()
# Out:
#   sample_id replicate replicate_count repeated_sample  batch  \
# 0     OF001      Rep1               1               0  cing1
# 1     OF001      Rep1               1               0  cing1
# 2     OF001      Rep1               1               0  cing1
# 3     OF001      Rep1               1               0  cing1
# 4     OF001      Rep1               1               0  cing1
#
#                          file_name                  file_type        src omic  \
# 0         possorted_genome_bam.bam        Per sample raw file  cingulate  RNA
# 1  OF001_cellranger_count_outs.tar  Per sample processed file  cingulate  RNA
# 2    OF001_S1_L001_I1_001.fastq.gz                      fastq  cingulate  RNA
# 3    OF001_S1_L001_I2_001.fastq.gz                      fastq  cingulate  RNA
# 4    OF001_S1_L001_R1_001.fastq.gz                      fastq  cingulate  RNA
#
#   adjustment technology file_description content  \
# 0        Raw         SN            Reads  Counts
# 1        Raw         SN           Counts  Counts
# 2        Raw         SN            Reads  Counts
# 3        Raw         SN            Reads  Counts
# 4        Raw         SN            Reads  Counts
#
#                            file_MD5 time header annotation configuration_file
# 0                               NaN   NA     NA         NA                 NA
# 1                               NaN   NA     NA         NA                 NA
# 2  74a74c8929b01a6da7e79b83f91a6607   NA     NA         NA                 NA
# 3  644d95728b50f1ff9db7becfa5b5c394   NA     NA         NA                 NA
# 4  129dfb6fe6115966e2cf2af5e3c82bdf   NA     NA         NA                 NA

# %%
SUBJECT['subject_id'].unique()
# Out:
# array(['SUL_T_4530', 'SUL_T_4105', 'SUL_T_5259', 'SUL_T_5385',
#        'SUL_T_2465', 'SUL_T_3799', 'SUL_T_4424', 'SUL_T_5133',
#        'SUL_T_5227', 'SUL_T_5547', 'SUL_T_5359', 'SUL_T_4116',
#        'SUL_T_4839', 'SUL_T_2007', 'SUL_T_4938', 'SUL_T_5498',
#        'SUL_T_2791', 'SUL_T_4695', 'SUL_T_4934', 'SUL_T_3870',
#        'SUL_T_124', 'SUL_T_81', 'SUL_T_4515', 'SUL_T_4235', 'SUL_T_4815',
#        'SUL_T_4857', 'SUL_T_3998', 'SUL_T_4462', 'SUL_T_4108',
#        'SUL_T_4174', 'SUL_T_3860', 'SUL_T_4162', 'SUL_T_4210',
#        'SUL_T_233', 'SUL_T_1976', 'SUL_T_2017', 'SUL_T_308', 'SUL_T_1952',
#        'SUL_T_777', 'SUL_T_1619', 'SUL_T_290', 'SUL_T_551', 'SUL_T_257',
#        'SUL_T_343', 'SUL_T_362'], dtype=object)

# %%
CLINPATH['subject_id'].unique()
# Out:
# array(['SUL_T_4530', 'SUL_T_4105', 'SUL_T_5259', 'SUL_T_5385',
#        'SUL_T_2465', 'SUL_T_3799', 'SUL_T_4424', 'SUL_T_5133',
#        'SUL_T_5227', 'SUL_T_5547', 'SUL_T_5359', 'SUL_T_4116',
#        'SUL_T_4839', 'SUL_T_2007', 'SUL_T_4938', 'SUL_T_5498',
#        'SUL_T_2791', 'SUL_T_4695', 'SUL_T_4934', 'SUL_T_3870',
#        'SUL_T_124', 'SUL_T_81', 'SUL_T_4515', 'SUL_T_4235', 'SUL_T_4815',
#        'SUL_T_4857', 'SUL_T_3998', 'SUL_T_4462', 'SUL_T_4108',
#        'SUL_T_4174', 'SUL_T_3860', 'SUL_T_4162', 'SUL_T_4210',
#        'SUL_T_233', 'SUL_T_1976', 'SUL_T_2017', 'SUL_T_308', 'SUL_T_1952',
#        'SUL_T_777', 'SUL_T_1619', 'SUL_T_290', 'SUL_T_551', 'SUL_T_257',
#        'SUL_T_343', 'SUL_T_362'], dtype=object)

# %%
SUBJECT['subject_id'].unique()
# CLINPATH.head()
# Out:
# array(['SUL_T_4530', 'SUL_T_4105', 'SUL_T_5259', 'SUL_T_5385',
#        'SUL_T_2465', 'SUL_T_3799', 'SUL_T_4424', 'SUL_T_5133',
#        'SUL_T_5227', 'SUL_T_5547', 'SUL_T_5359', 'SUL_T_4116',
#        'SUL_T_4839', 'SUL_T_2007', 'SUL_T_4938', 'SUL_T_5498',
#        'SUL_T_2791', 'SUL_T_4695', 'SUL_T_4934', 'SUL_T_3870',
#        'SUL_T_124', 'SUL_T_81', 'SUL_T_4515', 'SUL_T_4235', 'SUL_T_4815',
#        'SUL_T_4857', 'SUL_T_3998', 'SUL_T_4462', 'SUL_T_4108',
#        'SUL_T_4174', 'SUL_T_3860', 'SUL_T_4162', 'SUL_T_4210',
#        'SUL_T_233', 'SUL_T_1976', 'SUL_T_2017', 'SUL_T_308', 'SUL_T_1952',
#        'SUL_T_777', 'SUL_T_1619', 'SUL_T_290', 'SUL_T_551', 'SUL_T_257',
#        'SUL_T_343', 'SUL_T_362'], dtype=object)

# %%
SAMPLE
# Out:
#    sample_id  subject_id source_sample_id replicate replicate_count  \
# 0      OF001   SUL_T_362               NA      Rep1               1
# 1      OF009   SUL_T_308               NA      Rep1               1
# 2      OF016  SUL_T_3860               NA      Rep1               1
# 3      OF005   SUL_T_290               NA      Rep1               1
# 4      OF013   SUL_T_233               NA      Rep1               1
# 5      OF018  SUL_T_4108               NA      Rep1               1
# 6      OF003   SUL_T_257               NA      Rep1               1
# 7      OF007   SUL_T_777               NA      Rep1               1
# 8      OF011  SUL_T_1976               NA      Rep1               1
# 9      OF015  SUL_T_4162               NA      Rep1               1
# 10     OF017  SUL_T_4174               NA      Rep1               1
# 11     OF002   SUL_T_343               NA      Rep1               1
# 12     OF004   SUL_T_551               NA      Rep1               1
# 13     OF006  SUL_T_1619               NA      Rep1               1
# 14     OF008  SUL_T_1952               NA      Rep1               1
# 15     OF010  SUL_T_2017               NA      Rep1               1
# 16     OF012  SUL_T_2465               NA      Rep1               1
# 17     OF014  SUL_T_4210               NA      Rep1               1
# 18      OJ15    SUL_T_81               NA      Rep1               1
# 19      OJ16   SUL_T_124               NA      Rep1               1
# 20      OJ22  SUL_T_2007               NA      Rep1               1
# 21       OJ5  SUL_T_2465               NA      Rep1               1
# 22       OJ2  SUL_T_2791               NA      Rep1               1
# 23       OJ4  SUL_T_3799               NA      Rep1               1
# 24      OJ17  SUL_T_3870               NA      Rep1               1
# 25      OJ10  SUL_T_3998               NA      Rep1               1
# 27      OJ24  SUL_T_4116               NA      Rep1               1
# 28      OJ13  SUL_T_4235               NA      Rep1               1
# 29       OJ3  SUL_T_4424               NA      Rep1               1
# 30       OJ1  SUL_T_4462               NA      Rep1               1
# 31      OJ14  SUL_T_4515               NA      Rep1               1
# 32       OJ9  SUL_T_4530               NA      Rep1               1
# 33      OJ19  SUL_T_4695               NA      Rep1               1
# 34      OJ12  SUL_T_4815               NA      Rep1               1
# 35      OJ23  SUL_T_4839               NA      Rep1               1
# 36      OJ11  SUL_T_4857               NA      Rep1               1
# 37      OJ18  SUL_T_4934               NA      Rep1               1
# 38      OJ21  SUL_T_4938               NA      Rep1               1
# 39      OJ28  SUL_T_5133               NA      Rep1               1
# 40      OJ27  SUL_T_5227               NA      Rep1               1
# 41       OJ7  SUL_T_5259               NA      Rep1               1
# 42      OJ25  SUL_T_5359               NA      Rep1               1
# 43       OJ6  SUL_T_5385               NA      Rep1               1
# 44      OJ20  SUL_T_5498               NA      Rep1               1
# 45      OJ26  SUL_T_5547               NA      Rep1               1
#
#    repeated_sample  batch tissue      brain_region hemisphere  ...  \
# 0                0  cing1  Brain  Cingulate Cortex         NA  ...
# 1                0  cing1  Brain  Cingulate Cortex         NA  ...
# 2                0  cing1  Brain  Cingulate Cortex         NA  ...
# 3                0  cing1  Brain  Cingulate Cortex         NA  ...
# 4                0  cing1  Brain  Cingulate Cortex         NA  ...
# 5                0  cing1  Brain  Cingulate Cortex         NA  ...
# 6                0  cing1  Brain  Cingulate Cortex         NA  ...
# 7                0  cing1  Brain  Cingulate Cortex         NA  ...
# 8                0  cing1  Brain  Cingulate Cortex         NA  ...
# 9                0  cing1  Brain  Cingulate Cortex         NA  ...
# 10               0  cing1  Brain  Cingulate Cortex         NA  ...
# 11               0  cing1  Brain  Cingulate Cortex         NA  ...
# 12               0  cing1  Brain  Cingulate Cortex         NA  ...
# 13               0  cing1  Brain  Cingulate Cortex         NA  ...
# 14               0  cing1  Brain  Cingulate Cortex         NA  ...
# 15               0  cing1  Brain  Cingulate Cortex         NA  ...
# 16               0  cing1  Brain  Cingulate Cortex         NA  ...
# 17               0  cing1  Brain  Cingulate Cortex         NA  ...
# 18               0    sn1  Brain  Substantia Nigra         NA  ...
# 19               0    sn1  Brain  Substantia Nigra         NA  ...
# 20               0    sn1  Brain  Substantia Nigra         NA  ...
# 21               0    sn1  Brain  Substantia Nigra         NA  ...
# 22               0    sn1  Brain  Substantia Nigra         NA  ...
# 23               0    sn1  Brain  Substantia Nigra         NA  ...
# 24               0    sn1  Brain  Substantia Nigra         NA  ...
# 25               0    sn1  Brain  Substantia Nigra         NA  ...
# 27               0    sn1  Brain  Substantia Nigra         NA  ...
# 28               0    sn1  Brain  Substantia Nigra         NA  ...
# 29               0    sn1  Brain  Substantia Nigra         NA  ...
# 30               0    sn1  Brain  Substantia Nigra         NA  ...
# 31               0    sn1  Brain  Substantia Nigra         NA  ...
# 32               0    sn1  Brain  Substantia Nigra         NA  ...
# 33               0    sn1  Brain  Substantia Nigra         NA  ...
# 34               0    sn1  Brain  Substantia Nigra         NA  ...
# 35               0    sn1  Brain  Substantia Nigra         NA  ...
# 36               0    sn1  Brain  Substantia Nigra         NA  ...
# 37               0    sn1  Brain  Substantia Nigra         NA  ...
# 38               0    sn1  Brain  Substantia Nigra         NA  ...
# 39               0    sn1  Brain  Substantia Nigra         NA  ...
# 40               0    sn1  Brain  Substantia Nigra         NA  ...
# 41               0    sn1  Brain  Substantia Nigra         NA  ...
# 42               0    sn1  Brain  Substantia Nigra         NA  ...
# 43               0    sn1  Brain  Substantia Nigra         NA  ...
# 44               0    sn1  Brain  Substantia Nigra         NA  ...
# 45               0    sn1  Brain  Substantia Nigra         NA  ...
#
#    self_reported_ethnicity_ontology_term_id disease_ontology_term_id  \
# 0                                   Unknown                       NA
# 1                                   Unknown                       NA
# 2                                   Unknown                       NA
# 3                                   Unknown                       NA
# 4                                   Unknown                       NA
# 5                                   Unknown                       NA
# 6                                   Unknown                       NA
# 7                                   Unknown                       NA
# 8                                   Unknown                       NA
# 9                                   Unknown                       NA
# 10                                  Unknown                       NA
# 11                                  Unknown                       NA
# 12                                  Unknown                       NA
# 13                                  Unknown                       NA
# 14                                  Unknown                       NA
# 15                                  Unknown                       NA
# 16                                  Unknown                       NA
# 17                                  Unknown                       NA
# 18                                  Unknown                       NA
# 19                                  Unknown                       NA
# 20                                  Unknown                       NA
# 21                                  Unknown                       NA
# 22                                  Unknown                       NA
# 23                                  Unknown                       NA
# 24                                  Unknown                       NA
# 25                                  Unknown                       NA
# 27                                  Unknown                       NA
# 28                                  Unknown                       NA
# 29                                  Unknown                       NA
# 30                                  Unknown                       NA
# 31                                  Unknown                       NA
# 32                                  Unknown                       NA
# 33                                  Unknown                       NA
# 34                                  Unknown                       NA
# 35                                  Unknown                       NA
# 36                                  Unknown                       NA
# 37                                  Unknown                       NA
# 38                                  Unknown                       NA
# 39                                  Unknown                       NA
# 40                                  Unknown                       NA
# 41                                  Unknown                       NA
# 42                                  Unknown                       NA
# 43                                  Unknown                       NA
# 44                                  Unknown                       NA
# 45                                  Unknown                       NA
#
#    tissue_ontology_term_id cell_type_ontology_term_id assay_ontology_term_id  \
# 0           UBERON:0003027                         NA                     NA
# 1           UBERON:0003027                         NA                     NA
# 2           UBERON:0003027                         NA                     NA
# 3           UBERON:0003027                         NA                     NA
# 4           UBERON:0003027                         NA                     NA
# 5           UBERON:0003027                         NA                     NA
# 6           UBERON:0003027                         NA                     NA
# 7           UBERON:0003027                         NA                     NA
# 8           UBERON:0003027                         NA                     NA
# 9           UBERON:0003027                         NA                     NA
# 10          UBERON:0003027                         NA                     NA
# 11          UBERON:0003027                         NA                     NA
# 12          UBERON:0003027                         NA                     NA
# 13          UBERON:0003027                         NA                     NA
# 14          UBERON:0003027                         NA                     NA
# 15          UBERON:0003027                         NA                     NA
# 16          UBERON:0003027                         NA                     NA
# 17          UBERON:0003027                         NA                     NA
# 18          UBERON:0002037                         NA                     NA
# 19          UBERON:0002038                         NA                     NA
# 20          UBERON:0002037                         NA                     NA
# 21          UBERON:0002038                         NA                     NA
# 22          UBERON:0002037                         NA                     NA
# 23          UBERON:0002038                         NA                     NA
# 24          UBERON:0002037                         NA                     NA
# 25          UBERON:0002038                         NA                     NA
# 27          UBERON:0002038                         NA                     NA
# 28          UBERON:0002037                         NA                     NA
# 29          UBERON:0002038                         NA                     NA
# 30          UBERON:0002037                         NA                     NA
# 31          UBERON:0002038                         NA                     NA
# 32          UBERON:0002037                         NA                     NA
# 33          UBERON:0002038                         NA                     NA
# 34          UBERON:0002037                         NA                     NA
# 35          UBERON:0002038                         NA                     NA
# 36          UBERON:0002037                         NA                     NA
# 37          UBERON:0002038                         NA                     NA
# 38          UBERON:0002037                         NA                     NA
# 39          UBERON:0002038                         NA                     NA
# 40          UBERON:0002037                         NA                     NA
# 41          UBERON:0002038                         NA                     NA
# 42          UBERON:0002037                         NA                     NA
# 43          UBERON:0002038                         NA                     NA
# 44          UBERON:0002037                         NA                     NA
# 45          UBERON:0002038                         NA                     NA
#
#    suspension_type DV200 pm_PH donor_id alternate_sample_id
# 0          Nucleus    NA    NA       NA                  NA
# 1          Nucleus    NA    NA       NA                  NA
# 2          Nucleus    NA    NA       NA                  NA
# 3          Nucleus    NA    NA       NA                  NA
# 4          Nucleus    NA    NA       NA                  NA
# 5          Nucleus    NA    NA       NA                  NA
# 6          Nucleus    NA    NA       NA                  NA
# 7          Nucleus    NA    NA       NA                  NA
# 8          Nucleus    NA    NA       NA                  NA
# 9          Nucleus    NA    NA       NA                  NA
# 10         Nucleus    NA    NA       NA                  NA
# 11         Nucleus    NA    NA       NA                  NA
# 12         Nucleus    NA    NA       NA                  NA
# 13         Nucleus    NA    NA       NA                  NA
# 14         Nucleus    NA    NA       NA                  NA
# 15         Nucleus    NA    NA       NA                  NA
# 16         Nucleus    NA    NA       NA                  NA
# 17         Nucleus    NA    NA       NA                  NA
# 18         Nucleus    NA    NA       NA                  NA
# 19         Nucleus    NA    NA       NA                  NA
# 20         Nucleus    NA    NA       NA                  NA
# 21         Nucleus    NA    NA       NA                  NA
# 22         Nucleus    NA    NA       NA                  NA
# 23         Nucleus    NA    NA       NA                  NA
# 24         Nucleus    NA    NA       NA                  NA
# 25         Nucleus    NA    NA       NA                  NA
# 27         Nucleus    NA    NA       NA                  NA
# 28         Nucleus    NA    NA       NA                  NA
# 29         Nucleus    NA    NA       NA                  NA
# 30         Nucleus    NA    NA       NA                  NA
# 31         Nucleus    NA    NA       NA                  NA
# 32         Nucleus    NA    NA       NA                  NA
# 33         Nucleus    NA    NA       NA                  NA
# 34         Nucleus    NA    NA       NA                  NA
# 35         Nucleus    NA    NA       NA                  NA
# 36         Nucleus    NA    NA       NA                  NA
# 37         Nucleus    NA    NA       NA                  NA
# 38         Nucleus    NA    NA       NA                  NA
# 39         Nucleus    NA    NA       NA                  NA
# 40         Nucleus    NA    NA       NA                  NA
# 41         Nucleus    NA    NA       NA                  NA
# 42         Nucleus    NA    NA       NA                  NA
# 43         Nucleus    NA    NA       NA                  NA
# 44         Nucleus    NA    NA       NA                  NA
# 45         Nucleus    NA    NA       NA                  NA
#
# [45 rows x 34 columns]

# %%
dict(zip(CLINPATH['subject_id'], CLINPATH['path_autopsy_dx_main']))
# Out:
# {'SUL_T_4530': "Parkinson's disease with dementia",
#  'SUL_T_4105': "Alzheimer's disease (intermediate level neuropathological change)",
#  'SUL_T_5259': "Parkinson's disease with dementia",
#  'SUL_T_5385': 'Control, Primary age-related tauopathy (PART)',
#  'SUL_T_2465': 'Control, Low level AD neuropathological change',
#  'SUL_T_3799': 'Other neurological disorder',
#  'SUL_T_4424': "Parkinson's disease with dementia",
#  'SUL_T_5133': "Alzheimer's disease (intermediate level neuropathological change)",
#  'SUL_T_5227': "Alzheimer's disease (intermediate level neuropathological change)",
#  'SUL_T_5547': 'Control, Primary age-related tauopathy (PART)',
#  'SUL_T_5359': "Alzheimer's disease (intermediate level neuropathological change)",
#  'SUL_T_4116': "Alzheimer's disease (intermediate level neuropathological change)",
#  'SUL_T_4839': "Parkinson's disease with dementia",
#  'SUL_T_2007': "Parkinson's disease with dementia",
#  'SUL_T_4938': "Parkinson's disease with dementia",
#  'SUL_T_5498': "Parkinson's disease with dementia",
#  'SUL_T_2791': 'Control, Low level AD neuropathological change',
#  'SUL_T_4695': "Parkinson's disease with dementia",
#  'SUL_T_4934': "Parkinson's disease with dementia",
#  'SUL_T_3870': 'Control, Limbic predominant age-related TDP43 proteinopathy (LATE)',
#  'SUL_T_124': "Parkinson's disease with dementia",
#  'SUL_T_81': "Parkinson's disease with dementia",
#  'SUL_T_4515': "Parkinson's disease with dementia",
#  'SUL_T_4235': 'Control, Low level AD neuropathological change',
#  'SUL_T_4815': "Parkinson's disease",
#  'SUL_T_4857': "Alzheimer's disease (intermediate level neuropathological change)",
#  'SUL_T_3998': 'Control, Low level AD neuropathological change',
#  'SUL_T_4462': 'Control, Low level AD neuropathological change',
#  'SUL_T_4108': "Parkinson's disease with dementia",
#  'SUL_T_4174': 'Control, no misfolded protein or significant vascular pathology',
#  'SUL_T_3860': "Parkinson's disease with dementia",
#  'SUL_T_4162': "Parkinson's disease with dementia",
#  'SUL_T_4210': 'Control, Low level AD neuropathological change',
#  'SUL_T_233': "Parkinson's disease with dementia",
#  'SUL_T_1976': "Parkinson's disease with dementia",
#  'SUL_T_2017': 'Control, Low level AD neuropathological change',
#  'SUL_T_308': "Parkinson's disease with dementia",
#  'SUL_T_1952': 'Control, Low level AD neuropathological change',
#  'SUL_T_777': "Parkinson's disease with dementia",
#  'SUL_T_1619': 'Control, no misfolded protein or significant vascular pathology',
#  'SUL_T_290': "Parkinson's disease with dementia",
#  'SUL_T_551': 'Control, no misfolded protein or significant vascular pathology',
#  'SUL_T_257': "Parkinson's disease with dementia",
#  'SUL_T_343': 'Control, no misfolded protein or significant vascular pathology',
#  'SUL_T_362': "Parkinson's disease with dementia"}

# %%
SUBJECT['primary_diagnosis'] = SUBJECT['subject_id'].map(dict(zip(CLINPATH['subject_id'], CLINPATH['path_autopsy_dx_main'])))
SUBJECT['primary_diagnosis']
# Out:
# 0                     Parkinson's disease with dementia
# 1     Alzheimer's disease (intermediate level neurop...
# 2                     Parkinson's disease with dementia
# 3         Control, Primary age-related tauopathy (PART)
# 4        Control, Low level AD neuropathological change
# 5                           Other neurological disorder
# 6                     Parkinson's disease with dementia
# 7     Alzheimer's disease (intermediate level neurop...
# 8     Alzheimer's disease (intermediate level neurop...
# 9         Control, Primary age-related tauopathy (PART)
# 10    Alzheimer's disease (intermediate level neurop...
# 11    Alzheimer's disease (intermediate level neurop...
# 12                    Parkinson's disease with dementia
# 13                    Parkinson's disease with dementia
# 14                    Parkinson's disease with dementia
# 15                    Parkinson's disease with dementia
# 16       Control, Low level AD neuropathological change
# 17                    Parkinson's disease with dementia
# 18                    Parkinson's disease with dementia
# 19    Control, Limbic predominant age-related TDP43 ...
# 20                    Parkinson's disease with dementia
# 21                    Parkinson's disease with dementia
# 22                    Parkinson's disease with dementia
# 23       Control, Low level AD neuropathological change
# 24                                  Parkinson's disease
# 25    Alzheimer's disease (intermediate level neurop...
# 26       Control, Low level AD neuropathological change
# 27       Control, Low level AD neuropathological change
# 28                    Parkinson's disease with dementia
# 29    Control, no misfolded protein or significant v...
# 30                    Parkinson's disease with dementia
# 31                    Parkinson's disease with dementia
# 32       Control, Low level AD neuropathological change
# 33                    Parkinson's disease with dementia
# 34       Control, Low level AD neuropathological change
# 35                    Parkinson's disease with dementia
# 36       Control, Low level AD neuropathological change
# 37                    Parkinson's disease with dementia
# 38       Control, Low level AD neuropathological change
# 39                    Parkinson's disease with dementia
# 40    Control, no misfolded protein or significant v...
# 41                    Parkinson's disease with dementia
# 42    Control, no misfolded protein or significant v...
# 43                    Parkinson's disease with dementia
# 44    Control, no misfolded protein or significant v...
# 45                    Parkinson's disease with dementia
# Name: primary_diagnosis, dtype: object

# %%
# via chatGPT
diagnosis_mapping = {
    "Parkinson's disease with dementia": "Dementia with Lewy bodies",
    "Alzheimer's disease (intermediate level neuropathological change)": "Alzheimer's disease",
    "Control, Primary age-related tauopathy (PART)": "Other neurological disorder",
    "Control, Low level AD neuropathological change": "Prodromal non-motor PD",
    "Control, Limbic predominant age-related TDP43 proteinopathy (LATE)": "Frontotemporal dementia",
    "Parkinson's disease": "Idiopathic PD",
    "Control, no misfolded protein or significant vascular pathology": "No PD nor other neurological disorder"
}


SUBJECT['primary_diagnosis'] = SUBJECT['primary_diagnosis'].replace(diagnosis_mapping)

# %%
v2_path = metadata_path / "v2"
STUDY.to_csv(v2_path / f"STUDY.csv", index=False)
SAMPLE.to_csv(v2_path / f"SAMPLE.csv", index=False)
SUBJECT.to_csv(v2_path / f"SUBJECT.csv", index=False)
PROTOCOL.to_csv(v2_path / f"PROTOCOL.csv", index=False)
CLINPATH.to_csv(v2_path / f"CLINPATH.csv", index=False)
DATA.to_csv(v2_path / f"DATA.csv", index=False)

# %% [markdown]
# ## validate v2 tables

# %%
CDE = CDEv2
tables = CDE['Table'].unique()
dfs = {}
for table in tables:
    schema = CDE[CDE['Table'] == table]
    df = read_meta_table(v2_path / f"{table}.csv")
    report = ReportCollector(destination="NA")
    full_table, report = validate_table(df.copy(), table, schema, report)
    dfs[table] = full_table
    report.print_log()
# Out:
# recoding number_of_brain_samples as int
# All required fields are present in *STUDY* table.
# 🚨⚠️❗ **8 Fields with empty (NULL) values:**
#
# 	- ASAP_grant_id: 1/1 empty rows (REQUIRED)
#
# 	- other_funding_source: 1/1 empty rows (REQUIRED)
#
# 	- publication_DOI: 1/1 empty rows (REQUIRED)
#
# 	- publication_PMID: 1/1 empty rows (REQUIRED)
#
# 	- PI_ORCHID: 1/1 empty rows (OPTIONAL)
#
# 	- PI_google_scholar_id: 1/1 empty rows (OPTIONAL)
#
# 	- preprocessing_references: 1/1 empty rows (OPTIONAL)
#
# 	- alternate_dataset_id: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *PROTOCOL* table.
# 🚨⚠️❗ **3 Fields with empty (NULL) values:**
#
# 	- github_url: 1/1 empty rows (REQUIRED)
#
# 	- protocols_io_DOI: 1/1 empty rows (REQUIRED)
#
# 	- other_reference: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# All required fields are present in *SUBJECT* table.
# 🚨⚠️❗ **17 Fields with empty (NULL) values:**
#
# 	- AMPPD_id: 46/46 empty rows (REQUIRED)
#
# 	- GP2_id: 46/46 empty rows (REQUIRED)
#
# 	- race: 28/46 empty rows (REQUIRED)
#
# 	- ethnicity: 23/46 empty rows (REQUIRED)
#
# 	- family_history: 46/46 empty rows (REQUIRED)
#
# 	- age_at_onset: 46/46 empty rows (REQUIRED)
#
# 	- age_at_diagnosis: 46/46 empty rows (REQUIRED)
#
# 	- first_motor_symptom: 46/46 empty rows (REQUIRED)
#
# 	- hx_dementia_mci: 46/46 empty rows (REQUIRED)
#
# 	- hx_melanoma: 46/46 empty rows (REQUIRED)
#
# 	- education_level: 46/46 empty rows (REQUIRED)
#
# 	- smoking_status: 46/46 empty rows (REQUIRED)
#
# 	- smoking_years: 46/46 empty rows (OPTIONAL)
#
# 	- APOE_e4_status: 46/46 empty rows (REQUIRED)
#
# 	- cognitive_status: 46/46 empty rows (REQUIRED)
#
# 	- time_from_baseline: 46/46 empty rows (REQUIRED)
#
# 	- primary_diagnosis_text: 46/46 empty rows (OPTIONAL)
# 🚨⚠️❗ **1 Fields with invalid entries:**
# - _*age_at_collection*_:  invalid values 💩'77', '89+ ', '79', '88', '83', '78', '87', '75', '86', '85', '68', '73', '80', '72', '71', '50', '74', '81', '70', '66', '62'
#     - valid ➡️ float or NULL ('NA')
#
# All required fields are present in *CLINPATH* table.
# 🚨⚠️❗ **28 Fields with empty (NULL) values:**
#
# 	- path_autopsy_second_dx: 44/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_third_dx: 30/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_fourth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_fifth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_sixth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_seventh_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_eight_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_year_death: 46/46 empty rows (REQUIRED)
#
# 	- cause_death: 46/46 empty rows (REQUIRED)
#
# 	- other_cause_death_1: 46/46 empty rows (OPTIONAL)
#
# 	- other_cause_death_2: 46/46 empty rows (OPTIONAL)
#
# 	- brain_weight: 46/46 empty rows (REQUIRED)
#
# 	- path_braak_nft: 1/46 empty rows (REQUIRED)
#
# 	- path_cerad: 19/46 empty rows (REQUIRED)
#
# 	- path_thal: 46/46 empty rows (REQUIRED)
#
# 	- known_pathogenic_mutation: 46/46 empty rows (OPTIONAL)
#
# 	- PD_pathogenic_mutation: 46/46 empty rows (OPTIONAL)
#
# 	- path_mckeith: 46/46 empty rows (OPTIONAL)
#
# 	- sn_neuronal_loss: 46/46 empty rows (OPTIONAL)
#
# 	- path_infarcs: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_ri: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_a: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_b: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_c: 46/46 empty rows (OPTIONAL)
#
# 	- TDP43: 46/46 empty rows (OPTIONAL)
#
# 	- arteriolosclerosis_severity_scale: 46/46 empty rows (OPTIONAL)
#
# 	- amyloid_angiopathy_severity_scale: 46/46 empty rows (OPTIONAL)
#
# 	- path_ad_level: 46/46 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# recoding input_cell_count as int
# All required fields are present in *SAMPLE* table.
# 🚨⚠️❗ **14 Fields with empty (NULL) values:**
#
# 	- source_sample_id: 45/45 empty rows (REQUIRED)
#
# 	- hemisphere: 45/45 empty rows (REQUIRED)
#
# 	- region_level_2: 18/45 empty rows (REQUIRED)
#
# 	- RIN: 27/45 empty rows (REQUIRED)
#
# 	- source_RIN: 45/45 empty rows (REQUIRED)
#
# 	- input_cell_count: 27/45 empty rows (REQUIRED)
#
# 	- self_reported_ethnicity_ontology_term_id: 45/45 empty rows (REQUIRED)
#
# 	- disease_ontology_term_id: 45/45 empty rows (REQUIRED)
#
# 	- cell_type_ontology_term_id: 45/45 empty rows (REQUIRED)
#
# 	- assay_ontology_term_id: 45/45 empty rows (REQUIRED)
#
# 	- DV200: 45/45 empty rows (OPTIONAL)
#
# 	- pm_PH: 45/45 empty rows (OPTIONAL)
#
# 	- donor_id: 45/45 empty rows (OPTIONAL)
#
# 	- alternate_sample_id: 45/45 empty rows (OPTIONAL)
# 🚨⚠️❗ **1 Fields with invalid entries:**
# - _*input_cell_count*_:  invalid values 💩'915.1258 ng', '1411.8474 ng', '1608.6002 ng', '704.4034 ng', '1444.6272 ng', '896.3852 ng', '2392.286 ng', '714.5692 ng', '923.9646 ng', '866.4158 ng', '1420.8972 ng', '2169.106 ng', '1069.3564 ng', '1192.589 ng', '1008.9174 ng', '983.9328 ng', '1266.1952 ng', '945.216 ng', 'NA'
#     - valid ➡️ int or NULL ('NA')
#
# recoding replicate_count as int
# recoding repeated_sample as int
# All required fields are present in *DATA* table.
# 🚨⚠️❗ **5 Fields with empty (NULL) values:**
#
# 	- file_MD5: 63/711 empty rows (REQUIRED)
#
# 	- time: 711/711 empty rows (REQUIRED)
#
# 	- header: 711/711 empty rows (REQUIRED)
#
# 	- annotation: 711/711 empty rows (REQUIRED)
#
# 	- configuration_file: 711/711 empty rows (REQUIRED)
# No invalid entries found in Enum fields.
# 🚨⚠️❗ **Extra field in DATA: src**

# %%
tables
# Out:
# array(['STUDY', 'PROTOCOL', 'SUBJECT', 'CLINPATH', 'SAMPLE', 'DATA'],
#       dtype=object)

# %% [markdown]
# ### save extras as auxillary tables

# %%
CDE = CDEv2
tables = CDE['Table'].unique()

dfs = {}
for table in tables:
    df = read_meta_table(v2_path / f"{table}.csv")
    schema = CDE[CDE['Table'] == table]

    valid_fields = schema['Field'].unique()
    df_out = df[valid_fields]
    aux_fields = set(df.columns) - set(valid_fields)
    if aux_fields:
        df_aux = df[list(aux_fields)]
        df_aux.to_csv(v2_path / f"{table}_auxiliary.csv", index=False)
        print(f"Saved {table}_auxiliary.csv")
    df_out.to_csv(v2_path / f"{table}.csv", index=False)
    dfs[table] = df_out
# Out:
# Saved DATA_auxiliary.csv

# %%
# make tables conform to CDE and save extra columns as "auxiliary"
v2_path = metadata_path / "v2"

for table in tables:
    df = dfs[table]
    schema = CDE[CDE['Table'] == table]
    valid_fields = schema['Field'].unique()
    df_out = df[valid_fields]
    aux_fields = set(df.columns) - set(valid_fields)
    if aux_fields:
        df_aux = df[list(aux_fields)]
        df_aux.to_csv(v2_path / f"{table}_auxiliary.csv", index=False)
        print(f"Saved {table}_auxiliary.csv")
    df_out.to_csv(v2_path / f"{table}.csv", index=False)

# %% [markdown]
# validate v2 tables

# %%
CDE = CDEv2
v2_tables = dfs
for table,df in v2_tables.items():
    schema = CDE[CDE['Table'] == table]

    report = ReportCollector(destination="NA")
    full_table, report = validate_table(df.copy(), table, schema, report)
    report.print_log()
# Out:
# recoding number_of_brain_samples as int
# All required fields are present in *STUDY* table.
# 🚨⚠️❗ **8 Fields with empty (NULL) values:**
#
# 	- ASAP_grant_id: 1/1 empty rows (REQUIRED)
#
# 	- other_funding_source: 1/1 empty rows (REQUIRED)
#
# 	- publication_DOI: 1/1 empty rows (REQUIRED)
#
# 	- publication_PMID: 1/1 empty rows (REQUIRED)
#
# 	- PI_ORCHID: 1/1 empty rows (OPTIONAL)
#
# 	- PI_google_scholar_id: 1/1 empty rows (OPTIONAL)
#
# 	- preprocessing_references: 1/1 empty rows (OPTIONAL)
#
# 	- alternate_dataset_id: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *PROTOCOL* table.
# 🚨⚠️❗ **3 Fields with empty (NULL) values:**
#
# 	- github_url: 1/1 empty rows (REQUIRED)
#
# 	- protocols_io_DOI: 1/1 empty rows (REQUIRED)
#
# 	- other_reference: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# All required fields are present in *SUBJECT* table.
# 🚨⚠️❗ **17 Fields with empty (NULL) values:**
#
# 	- AMPPD_id: 46/46 empty rows (REQUIRED)
#
# 	- GP2_id: 46/46 empty rows (REQUIRED)
#
# 	- race: 28/46 empty rows (REQUIRED)
#
# 	- ethnicity: 23/46 empty rows (REQUIRED)
#
# 	- family_history: 46/46 empty rows (REQUIRED)
#
# 	- age_at_onset: 46/46 empty rows (REQUIRED)
#
# 	- age_at_diagnosis: 46/46 empty rows (REQUIRED)
#
# 	- first_motor_symptom: 46/46 empty rows (REQUIRED)
#
# 	- hx_dementia_mci: 46/46 empty rows (REQUIRED)
#
# 	- hx_melanoma: 46/46 empty rows (REQUIRED)
#
# 	- education_level: 46/46 empty rows (REQUIRED)
#
# 	- smoking_status: 46/46 empty rows (REQUIRED)
#
# 	- smoking_years: 46/46 empty rows (OPTIONAL)
#
# 	- APOE_e4_status: 46/46 empty rows (REQUIRED)
#
# 	- cognitive_status: 46/46 empty rows (REQUIRED)
#
# 	- time_from_baseline: 46/46 empty rows (REQUIRED)
#
# 	- primary_diagnosis_text: 46/46 empty rows (OPTIONAL)
# 🚨⚠️❗ **1 Fields with invalid entries:**
# - _*age_at_collection*_:  invalid values 💩'77', '89+ ', '79', '88', '83', '78', '87', '75', '86', '85', '68', '73', '80', '72', '71', '50', '74', '81', '70', '66', '62'
#     - valid ➡️ float or NULL ('NA')
#
# All required fields are present in *CLINPATH* table.
# 🚨⚠️❗ **28 Fields with empty (NULL) values:**
#
# 	- path_autopsy_second_dx: 44/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_third_dx: 30/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_fourth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_fifth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_sixth_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_seventh_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_autopsy_eight_dx: 46/46 empty rows (OPTIONAL)
#
# 	- path_year_death: 46/46 empty rows (REQUIRED)
#
# 	- cause_death: 46/46 empty rows (REQUIRED)
#
# 	- other_cause_death_1: 46/46 empty rows (OPTIONAL)
#
# 	- other_cause_death_2: 46/46 empty rows (OPTIONAL)
#
# 	- brain_weight: 46/46 empty rows (REQUIRED)
#
# 	- path_braak_nft: 1/46 empty rows (REQUIRED)
#
# 	- path_cerad: 19/46 empty rows (REQUIRED)
#
# 	- path_thal: 46/46 empty rows (REQUIRED)
#
# 	- known_pathogenic_mutation: 46/46 empty rows (OPTIONAL)
#
# 	- PD_pathogenic_mutation: 46/46 empty rows (OPTIONAL)
#
# 	- path_mckeith: 46/46 empty rows (OPTIONAL)
#
# 	- sn_neuronal_loss: 46/46 empty rows (OPTIONAL)
#
# 	- path_infarcs: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_ri: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_a: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_b: 46/46 empty rows (OPTIONAL)
#
# 	- path_nia_aa_c: 46/46 empty rows (OPTIONAL)
#
# 	- TDP43: 46/46 empty rows (OPTIONAL)
#
# 	- arteriolosclerosis_severity_scale: 46/46 empty rows (OPTIONAL)
#
# 	- amyloid_angiopathy_severity_scale: 46/46 empty rows (OPTIONAL)
#
# 	- path_ad_level: 46/46 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# recoding input_cell_count as int
# All required fields are present in *SAMPLE* table.
# 🚨⚠️❗ **14 Fields with empty (NULL) values:**
#
# 	- source_sample_id: 45/45 empty rows (REQUIRED)
#
# 	- hemisphere: 45/45 empty rows (REQUIRED)
#
# 	- region_level_2: 18/45 empty rows (REQUIRED)
#
# 	- RIN: 27/45 empty rows (REQUIRED)
#
# 	- source_RIN: 45/45 empty rows (REQUIRED)
#
# 	- input_cell_count: 27/45 empty rows (REQUIRED)
#
# 	- self_reported_ethnicity_ontology_term_id: 45/45 empty rows (REQUIRED)
#
# 	- disease_ontology_term_id: 45/45 empty rows (REQUIRED)
#
# 	- cell_type_ontology_term_id: 45/45 empty rows (REQUIRED)
#
# 	- assay_ontology_term_id: 45/45 empty rows (REQUIRED)
#
# 	- DV200: 45/45 empty rows (OPTIONAL)
#
# 	- pm_PH: 45/45 empty rows (OPTIONAL)
#
# 	- donor_id: 45/45 empty rows (OPTIONAL)
#
# 	- alternate_sample_id: 45/45 empty rows (OPTIONAL)
# 🚨⚠️❗ **1 Fields with invalid entries:**
# - _*input_cell_count*_:  invalid values 💩'915.1258 ng', '1411.8474 ng', '1608.6002 ng', '704.4034 ng', '1444.6272 ng', '896.3852 ng', '2392.286 ng', '714.5692 ng', '923.9646 ng', '866.4158 ng', '1420.8972 ng', '2169.106 ng', '1069.3564 ng', '1192.589 ng', '1008.9174 ng', '983.9328 ng', '1266.1952 ng', '945.216 ng', 'NA'
#     - valid ➡️ int or NULL ('NA')
#
# recoding replicate_count as int
# recoding repeated_sample as int
# All required fields are present in *DATA* table.
# 🚨⚠️❗ **5 Fields with empty (NULL) values:**
#
# 	- file_MD5: 63/711 empty rows (REQUIRED)
#
# 	- time: 711/711 empty rows (REQUIRED)
#
# 	- header: 711/711 empty rows (REQUIRED)
#
# 	- annotation: 711/711 empty rows (REQUIRED)
#
# 	- configuration_file: 711/711 empty rows (REQUIRED)
# No invalid entries found in Enum fields.

# %%
v2_tables["SUBJECT"][['subject_id','primary_diagnosis'] ]
    # primary_diagnosis = v3_tables["SUBJECT"]['primary_diagnosis'].str.lower().str.replace(" ", "_")
    # diagnosis_mapper = dict(zip(subject_id, primary_diagnosis))
v2_tables["SUBJECT"]['subject_id'].unique()
# Out:
# array(['SUL_T_4530', 'SUL_T_4105', 'SUL_T_5259', 'SUL_T_5385',
#        'SUL_T_2465', 'SUL_T_3799', 'SUL_T_4424', 'SUL_T_5133',
#        'SUL_T_5227', 'SUL_T_5547', 'SUL_T_5359', 'SUL_T_4116',
#        'SUL_T_4839', 'SUL_T_2007', 'SUL_T_4938', 'SUL_T_5498',
#        'SUL_T_2791', 'SUL_T_4695', 'SUL_T_4934', 'SUL_T_3870',
#        'SUL_T_124', 'SUL_T_81', 'SUL_T_4515', 'SUL_T_4235', 'SUL_T_4815',
#        'SUL_T_4857', 'SUL_T_3998', 'SUL_T_4462', 'SUL_T_4108',
#        'SUL_T_4174', 'SUL_T_3860', 'SUL_T_4162', 'SUL_T_4210',
#        'SUL_T_233', 'SUL_T_1976', 'SUL_T_2017', 'SUL_T_308', 'SUL_T_1952',
#        'SUL_T_777', 'SUL_T_1619', 'SUL_T_290', 'SUL_T_551', 'SUL_T_257',
#        'SUL_T_343', 'SUL_T_362'], dtype=object)

# %%
v2_tables["SAMPLE"]['subject_id'].unique()
# Out:
# array(['SUL_T_362', 'SUL_T_308', 'SUL_T_3860', 'SUL_T_290', 'SUL_T_233',
#        'SUL_T_4108', 'SUL_T_257', 'SUL_T_777', 'SUL_T_1976', 'SUL_T_4162',
#        'SUL_T_4174', 'SUL_T_343', 'SUL_T_551', 'SUL_T_1619', 'SUL_T_1952',
#        'SUL_T_2017', 'SUL_T_2465', 'SUL_T_4210', 'SUL_T_81', 'SUL_T_124',
#        'SUL_T_2007', 'SUL_T_2791', 'SUL_T_3799', 'SUL_T_3870',
#        'SUL_T_3998', 'SUL_T_4116', 'SUL_T_4235', 'SUL_T_4424',
#        'SUL_T_4462', 'SUL_T_4515', 'SUL_T_4530', 'SUL_T_4695',
#        'SUL_T_4815', 'SUL_T_4839', 'SUL_T_4857', 'SUL_T_4934',
#        'SUL_T_4938', 'SUL_T_5133', 'SUL_T_5227', 'SUL_T_5259',
#        'SUL_T_5359', 'SUL_T_5385', 'SUL_T_5498', 'SUL_T_5547'],
#       dtype=object)

# %% [markdown]
# ## v2->v3

# %%
v3_meta_tables = ['STUDY', 'PROTOCOL', 'SUBJECT', 'SAMPLE', 'DATA', 'CLINPATH', 'PMDBS', 'CONDITION', 'ASSAY_RNAseq']

f"{v3_meta_tables}"
# Out:
# "['STUDY', 'PROTOCOL', 'SUBJECT', 'SAMPLE', 'DATA', 'CLINPATH', 'PMDBS', 'CONDITION', 'ASSAY_RNAseq']"

# %%
v3_path = metadata_path / "v3"

v3_tables, aux_tables = v2_to_v3_PMDBS(v2_path, v3_path, CDEv2, CDEv3)
# Out:
# recoding number_of_brain_samples as int
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# recoding replicate_count as int
# recoding repeated_sample as int
# recoding input_cell_count as int
# recoding replicate_count as int
# recoding repeated_sample as int

# %% [markdown]
# ### validate v3 tables

# %%
CDE = CDEv3
for table,df in v3_tables.items():
    schema = CDE[CDE['Table'] == table]

    report = ReportCollector(destination="NA")
    full_table, report = validate_table(df.copy(), table, schema, report)
    report.print_log()
# Out:
# recoding number_samples as int
# All required fields are present in *STUDY* table.
# 🚨⚠️❗ **8 Fields with empty (NULL) values:**
#
# 	- ASAP_grant_id: 1/1 empty rows (REQUIRED)
#
# 	- other_funding_source: 1/1 empty rows (REQUIRED)
#
# 	- publication_DOI: 1/1 empty rows (REQUIRED)
#
# 	- publication_PMID: 1/1 empty rows (REQUIRED)
#
# 	- PI_ORCID: 1/1 empty rows (OPTIONAL)
#
# 	- PI_google_scholar_id: 1/1 empty rows (OPTIONAL)
#
# 	- preprocessing_references: 1/1 empty rows (OPTIONAL)
#
# 	- alternate_dataset_id: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *PROTOCOL* table.
# 🚨⚠️❗ **3 Fields with empty (NULL) values:**
#
# 	- github_url: 1/1 empty rows (REQUIRED)
#
# 	- protocols_io_DOI: 1/1 empty rows (REQUIRED)
#
# 	- other_reference: 1/1 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *SUBJECT* table.
# 🚨⚠️❗ **2 Fields with empty (NULL) values:**
#
# 	- race: 28/46 empty rows (REQUIRED)
#
# 	- primary_diagnosis_text: 46/46 empty rows (OPTIONAL)
# 🚨⚠️❗ **1 Fields with invalid entries:**
# - _*age_at_collection*_:  invalid values 💩'77', '89+ ', '79', '88', '83', '78', '87', '75', '86', '85', '68', '73', '80', '72', '71', '50', '74', '81', '70', '66', '62'
#     - valid ➡️ float or NULL ('NA')
#
# recoding replicate_count as int
# recoding repeated_sample as int
# All required fields are present in *SAMPLE* table.
# 🚨⚠️❗ **13 Fields with empty (NULL) values:**
#
# 	- source_sample_id: 45/45 empty rows (REQUIRED)
#
# 	- organism: 45/45 empty rows (REQUIRED)
#
# 	- assay_type: 45/45 empty rows (REQUIRED)
#
# 	- time: 45/45 empty rows (OPTIONAL)
#
# 	- alternate_id: 45/45 empty rows (OPTIONAL)
#
# 	- self_reported_ethnicity_ontology_term_id: 45/45 empty rows (OPTIONAL)
#
# 	- disease_ontology_term_id: 45/45 empty rows (OPTIONAL)
#
# 	- assay_ontology_term_id: 45/45 empty rows (OPTIONAL)
#
# 	- donor_id: 45/45 empty rows (OPTIONAL)
#
# 	- pm_PH: 45/45 empty rows (OPTIONAL)
#
# 	- cell_type_ontology_term_id: 45/45 empty rows (OPTIONAL)
#
# 	- source_RIN: 45/45 empty rows (OPTIONAL)
#
# 	- DV200: 45/45 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# recoding replicate_count as int
# recoding repeated_sample as int
# All required fields are present in *DATA* table.
# 🚨⚠️❗ **4 Fields with empty (NULL) values:**
#
# 	- file_MD5: 63/711 empty rows (REQUIRED)
#
# 	- header: 711/711 empty rows (OPTIONAL)
#
# 	- annotation: 711/711 empty rows (OPTIONAL)
#
# 	- configuration_file: 711/711 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *PMDBS* table.
# 🚨⚠️❗ **2 Fields with empty (NULL) values:**
#
# 	- hemisphere: 45/45 empty rows (OPTIONAL)
#
# 	- region_level_2: 18/45 empty rows (REQUIRED)
# No invalid entries found in Enum fields.
#
# recoding input_cell_count as int
# recoding sequencing_length as int
# All required fields are present in *ASSAY_RNAseq* table.
# 🚨⚠️❗ **2 Fields with empty (NULL) values:**
#
# 	- RIN: 27/45 empty rows (REQUIRED)
#
# 	- input_cell_count: 27/45 empty rows (REQUIRED)
# 🚨⚠️❗ **1 Fields with invalid entries:**
# - _*input_cell_count*_:  invalid values 💩'915.1258 ng', '1411.8474 ng', '1608.6002 ng', '704.4034 ng', '1444.6272 ng', '896.3852 ng', '2392.286 ng', '714.5692 ng', '923.9646 ng', '866.4158 ng', '1420.8972 ng', '2169.106 ng', '1069.3564 ng', '1192.589 ng', '1008.9174 ng', '983.9328 ng', '1266.1952 ng', '945.216 ng', 'NA'
#     - valid ➡️ int or NULL ('NA')
#
# recoding age_at_onset as int
# recoding age_at_diagnosis as int
# recoding first_motor_symptom as int
# All required fields are present in *CLINPATH* table.
# 🚨⚠️❗ **43 Fields with empty (NULL) values:**
#
# 	- AMPPD_id: 48/48 empty rows (OPTIONAL)
#
# 	- GP2_id: 48/48 empty rows (OPTIONAL)
#
# 	- ethnicity: 24/48 empty rows (OPTIONAL)
#
# 	- family_history: 48/48 empty rows (OPTIONAL)
#
# 	- age_at_onset: 48/48 empty rows (OPTIONAL)
#
# 	- age_at_diagnosis: 48/48 empty rows (OPTIONAL)
#
# 	- first_motor_symptom: 48/48 empty rows (OPTIONAL)
#
# 	- hx_dementia_mci: 48/48 empty rows (OPTIONAL)
#
# 	- hx_melanoma: 48/48 empty rows (OPTIONAL)
#
# 	- education_level: 48/48 empty rows (OPTIONAL)
#
# 	- smoking_status: 48/48 empty rows (OPTIONAL)
#
# 	- smoking_years: 48/48 empty rows (OPTIONAL)
#
# 	- APOE_e4_status: 48/48 empty rows (OPTIONAL)
#
# 	- cognitive_status: 48/48 empty rows (OPTIONAL)
#
# 	- time_from_baseline: 48/48 empty rows (OPTIONAL)
#
# 	- path_autopsy_second_dx: 46/48 empty rows (OPTIONAL)
#
# 	- path_autopsy_third_dx: 31/48 empty rows (OPTIONAL)
#
# 	- path_autopsy_fourth_dx: 48/48 empty rows (OPTIONAL)
#
# 	- path_autopsy_fifth_dx: 48/48 empty rows (OPTIONAL)
#
# 	- path_autopsy_sixth_dx: 48/48 empty rows (OPTIONAL)
#
# 	- path_autopsy_seventh_dx: 48/48 empty rows (OPTIONAL)
#
# 	- path_autopsy_eight_dx: 48/48 empty rows (OPTIONAL)
#
# 	- path_year_death: 48/48 empty rows (OPTIONAL)
#
# 	- cause_death: 48/48 empty rows (OPTIONAL)
#
# 	- other_cause_death_1: 48/48 empty rows (OPTIONAL)
#
# 	- other_cause_death_2: 48/48 empty rows (OPTIONAL)
#
# 	- brain_weight: 48/48 empty rows (OPTIONAL)
#
# 	- path_braak_nft: 1/48 empty rows (OPTIONAL)
#
# 	- path_cerad: 21/48 empty rows (OPTIONAL)
#
# 	- path_thal: 48/48 empty rows (OPTIONAL)
#
# 	- known_pathogenic_mutation: 48/48 empty rows (OPTIONAL)
#
# 	- PD_pathogenic_mutation: 48/48 empty rows (OPTIONAL)
#
# 	- path_mckeith: 48/48 empty rows (OPTIONAL)
#
# 	- sn_neuronal_loss: 48/48 empty rows (OPTIONAL)
#
# 	- path_infarcs: 48/48 empty rows (OPTIONAL)
#
# 	- path_nia_ri: 48/48 empty rows (OPTIONAL)
#
# 	- path_nia_aa_a: 48/48 empty rows (OPTIONAL)
#
# 	- path_nia_aa_b: 48/48 empty rows (OPTIONAL)
#
# 	- path_nia_aa_c: 48/48 empty rows (OPTIONAL)
#
# 	- TDP43: 48/48 empty rows (OPTIONAL)
#
# 	- arteriolosclerosis_severity_scale: 48/48 empty rows (OPTIONAL)
#
# 	- amyloid_angiopathy_severity_scale: 48/48 empty rows (OPTIONAL)
#
# 	- path_ad_level: 48/48 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.
#
# All required fields are present in *CONDITION* table.
# 🚨⚠️❗ **2 Fields with empty (NULL) values:**
#
# 	- protocol_id: 7/7 empty rows (REQUIRED)
#
# 	- intervention_aux_table: 7/7 empty rows (OPTIONAL)
# No invalid entries found in Enum fields.

# %%
STUDY = v3_tables['STUDY']
STUDY
# Out:
#   ASAP_team_name ASAP_lab_name  \
# 0    TEAM-SULZER   Al-Dalahmah
#
#                                         project_name team_dataset_id  \
# 0  The landscape of T-cell Immunity in Parkinson ...       sn_rnaseq
#
#      project_dataset                                project_description  \
# 0  OJK_2022_ASAP_SEQ  Assessing the role of T cells in Parkinson's d...
#
#         PI_full_name                  PI_email  \
# 0  Osama Al-Dalahmah  oa2298@cumc.columbia.edu
#
#                                    contributor_names  submitter_name  ...  \
# 0  Kelly A Jakubiak, Adithya Kannan, Jaeseung Lee...  Kelly Jakubiak  ...
#
#   number_samples                           sample_types  \
# 0             44  Cingulate Cortex and Substantia nigra
#
#             types_of_samples DUA_version  \
# 0  Postmortem PD and control          v1
#
#                                      metadata_tables PI_ORCID  \
# 0  ['STUDY', 'PROTOCOL', 'SUBJECT', 'SAMPLE', 'DA...       NA
#
#   PI_google_scholar_id preprocessing_references metadata_version_date  \
# 0                   NA                       NA         v3.0_20241028
#
#   alternate_dataset_id
# 0                   NA
#
# [1 rows x 25 columns]

# %% [markdown]
# -------------------------
# ## check md5s

# %%
print(team)

source = "pmdbs"

bucket = f"asap-raw-team-{team}-{source}-{dataset_name}"


key_file_path = Path.home() / f"Projects/ASAP/{team}-credentials.json"

res = authenticate_with_service_account(key_file_path)
print(res)

# make sure to get ALL the fastq files in the bucket
prefix = "**/*.gz"
bucket_files_md5 = get_md5_hashes( bucket, prefix)
# Out:
# sulzer
# CompletedProcess(args='gcloud auth activate-service-account --key-file=/Users/ergonyc/Projects/ASAP/sulzer-credentials.json', returncode=0, stdout='', stderr='Activated service account credentials for: [raw-admin-sulzer@dnastack-asap-parkinsons.iam.gserviceaccount.com]\n')
# gsutil -u dnastack-asap-parkinsons hash -h gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/**/*.gz

# %%
# def check_md5_sums()

v3_path = metadata_path / "v3"
data_df = read_meta_table(v3_path / "DATA.csv")

# checksum = v3_tables['DATA'][['file_name','file_MD5','file_type']].copy()

checksum = data_df[['file_name','file_MD5','file_type']].copy()
checksum = checksum[checksum.file_type == "fastq"]
checksum['check2'] = checksum['file_name'].map(bucket_files_md5)
checksum['check1'] = checksum['file_MD5']
checksum[checksum.check1 != checksum.check2].file_name.to_list()
#empty means success!!
# Out:
# []

# %% [markdown]
# _____
#
# ## prep metadata in raw data bucket
#
# steps:
# - 1. archive whats there.  i.e. move to metadata/upload
# - 2. copy metadata/upload to dataset upload (upload subdir)

# %%
metadata_subdir = "metadata"
current_files = gsutil_ls(bucket,metadata_subdir)
# Out:
# gsutil -u dnastack-asap-parkinsons ls gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata
# gsutil command succeeded: gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/CLINPATH.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/DATA.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/PROTOCOL.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/SAMPLE.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/STUDY.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/SUBJECT.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/v2-processed/
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/v2/

# %%
metadata_subdir2 = "metadata/upload"
bucket = current_files[0].split("/")[2]

for file in current_files:
    if file == "":
        continue
    file_nm = Path(file).name
    is_dir = not file_nm.__contains__(".")

    source = f"gs://{bucket}/{metadata_subdir}/{file_nm}"

    destination = f"gs://{bucket}/{metadata_subdir2}/{file_nm}"
    gsutil_mv(source, destination, is_dir)
# Out:
# gsutil -u dnastack-asap-parkinsons mv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/CLINPATH.csv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/CLINPATH.csv
# gsutil command succeeded:
# gsutil -u dnastack-asap-parkinsons mv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/DATA.csv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/DATA.csv
# gsutil command succeeded:
# gsutil -u dnastack-asap-parkinsons mv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/PROTOCOL.csv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/PROTOCOL.csv
# gsutil command succeeded:
# gsutil -u dnastack-asap-parkinsons mv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/SAMPLE.csv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/SAMPLE.csv
# gsutil command succeeded:
# gsutil -u dnastack-asap-parkinsons mv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/STUDY.csv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/STUDY.csv
# gsutil command succeeded:
# gsutil -u dnastack-asap-parkinsons mv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/SUBJECT.csv gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/SUBJECT.csv
# gsutil command succeeded:
# gsutil -u dnastack-asap-parkinsons mv -r gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/v2-processed gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/v2-processed
# gsutil command succeeded:
# gsutil -u dnastack-asap-parkinsons mv -r gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/v2 gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/v2
# gsutil command succeeded:

# %%
# verify
metadata_subdir = "metadata/upload"
current_files = gsutil_ls(bucket,metadata_subdir)
# Out:
# gsutil -u dnastack-asap-parkinsons ls gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload
# gsutil command succeeded: gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/CLINPATH.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/DATA.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/PROTOCOL.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/SAMPLE.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/STUDY.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/SUBJECT.csv
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/v2-processed/
# gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload/v2/

# %% [markdown]
# Archive the uploaded metadata locally

# %%
file_source = f"gs://{bucket}/{metadata_subdir}"
destination = f"{metadata_path}"
file_source, destination
# Out:
# ('gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload',
#  '/Users/ergonyc/Projects/ASAP/data/teams/sulzer/sn-rnaseq/metadata')

# %%
is_dir = True
gsutil_cp(file_source, destination, is_dir)
# Out:
# gsutil -u dnastack-asap-parkinsons cp -r gs://asap-raw-team-sulzer-pmdbs-sn-rnaseq/metadata/upload /Users/ergonyc/Projects/ASAP/data/teams/sulzer/sn-rnaseq/metadata
# gsutil command succeeded:
# ''

# %% [markdown]
# --------------------
# ## Create metadata package
#
# This will copy the final updated to v3.0 metadata to `asap-could-processing-resources`

# %%
metadata_source = metadata_path


source = "pmdbs"
archive_root = Path.home() / "Projects/ASAP/asap-crn-metadata/datasets"
dataset_path = archive_root / f"{team}-{source}-{dataset_name}"
# bucket = f"asap-raw-data-team-{team}" # for now old locations
metadata_source, dataset_path
# Out:
# (PosixPath('/Users/ergonyc/Projects/ASAP/data/teams/sulzer/sn-rnaseq/metadata'),
#  PosixPath('/Users/ergonyc/Projects/ASAP/asap-crn-metadata/datasets/sulzer-pmdbs-sn-rnaseq'))

# %% [markdown]
# ________

# %%
fnms = create_metadata_package(metadata_source, dataset_path)
# Out:
# Copied /Users/ergonyc/Projects/ASAP/data/teams/sulzer/sn-rnaseq/metadata/v2 to /Users/ergonyc/Projects/ASAP/asap-crn-metadata/datasets/sulzer-pmdbs-sn-rnaseq/metadata/v2
# Copied /Users/ergonyc/Projects/ASAP/data/teams/sulzer/sn-rnaseq/metadata/v3 to /Users/ergonyc/Projects/ASAP/asap-crn-metadata/datasets/sulzer-pmdbs-sn-rnaseq/metadata/v3
# Copied /Users/ergonyc/Projects/ASAP/data/teams/sulzer/sn-rnaseq/metadata/og to /Users/ergonyc/Projects/ASAP/asap-crn-metadata/datasets/sulzer-pmdbs-sn-rnaseq/metadata/og
# Copied /Users/ergonyc/Projects/ASAP/data/teams/sulzer/sn-rnaseq/metadata/upload to /Users/ergonyc/Projects/ASAP/asap-crn-metadata/datasets/sulzer-pmdbs-sn-rnaseq/metadata/upload

# %% [markdown]
# _____
#
# generate ASAP IDs + transfering back to raw data bucket via `asap-crn-metadata`

# %% [markdown]
# _____
#
# ## transfer metadata to raw data bucket
#
# steps:
# - 1. archive whats there.  i.e. move to metadata/archive
# - 2. copy package to metadata/ . i.e. /og/*.csv, /v??/*.csv
